# %% [markdown]
# URL del repositorio en GitHub: https://github.com/dcm00/PIDs-DOIs/blob/main/DOI.ipynb

# %% [markdown]
# # DOI Negotiation

# %% [markdown]
# # David Cahill Marrón

# %% [markdown]
# <div class="alert alert-warning" role="alert" style="margin: 10px">
# Librerías que usaremos:<br>
# requests<br>
# json
# </div>

# %%
import requests
import json

# %% [markdown]
# ## 1 Introduction
#
# DOIs provide a persistent link to content. They identify many types of work, from journal articles to research data sets. Typically, someone interacting with DOIs will be a researcher, who will resolve DOIs found in scholarly references to content using a DOI resolver. Such researchers may not even realise they are using DOIs and a DOI resolver since they may follow links with embedded DOIs.
#
# Yet DOIs can provide more than a permanent, indirect link to content. DOI registration agencies such as CrossRef, DataCite and mEDRA collect bibliographic metadata about the works they link to. This metadata can be retrieved from a DOI resolver too, using content negotiation to request a particular representation of the metadata.
#
# For some DOIs content negotiation can be used to retrieve different representations of a work. For example, some DataCite DOIs identify data sets that may be available in a number of data formats and container formats.

# %% [markdown]
# ## 2 Redirection
#
# The DOI resolver at doi.org will normally redirect a user to the resource location of a DOI. For example, the DOI "10.1126/science.169.3946.635" redirects to a landing page describing the article, "The Structure of Ordinary Water". Content negotiated requests to doi.org that ask for a content type which isn't "text/html" will be redirected to a metadata service hosted by the DOI's registration agency. CrossRef, DataCite and mEDRA support content negotiated DOIs via https://data.crossref.org, https://data.datacite.org and http://data.medra.org respectively.
#
# <div class="alert alert-warning" role="alert" style="margin: 10px">
#
#        GET "Accept: text/html"
# https://doi.org/10.1126/science.169.3946.635<br>
#
#                    |<br>
#                    |<br>
#                    |<br>
#                    V<br>
# <br>
#        Publisher landing page
# https://www.sciencemag.org/content/169/3946/635
# </div>
#
# Normal browser requests or explicit requests for text/html redirect to the content's landing page.
#
# <div class="alert alert-warning" role="alert" style="margin: 10px">
#
#              GET "Accept: application/rdf+xml"
# https://doi.org/10.1126/science.169.3946.635<br>
#
#                    |<br>
#                    |<br>
#                    |<br>
#                    V<br>
# <br>
# CrossRef metadata service
# http://data.crossref.org/10.1126/science.169.3946.635
# </div>
#
# Requests for a data type redirect to a registration agency's metadata service.

# %% [markdown]
# ## 3 What is Content Negotiation?
#
# Content negotiation allows a user to request a particular representation of a web resource. DOI resolvers use content negotiation to provide different representations of metadata associated with DOIs.
#
# A content negotiated request to a DOI resolver is much like a standard HTTP request, except server-driven negotiation will take place based on the list of acceptable content types a client provides.

# %% [markdown]
# ### 3.1 The Accept Header
#
# Making a content negotiated request requires the use of a HTTP header, "Accept". Content types that are acceptable to the client (those that it knows how to parse), each with an optional "quality" value indicating its relative suitability. For example, a client that wishes to receive citeproc JSON if it is available, but which can also handle RDF XML if citeproc JSON is unavailable, would make a request with an Accept header listing both "application/citeproc+json" and "application/rdf+xml":

# %%
import requests

url = "https://doi.org/10.13140/rg.2.1.4785.1282" #DOI solver URL
r = requests.get(url) #GET without headers
print(r.status_code)
print(r.text)
# Out:
# 200
# <!DOCTYPE html>
# <html lang="en">
# <head prefix="og: http://ogp.me/ns#">
#     <meta charset="utf-8">
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#     <meta name="referrer" content="origin">
#     <meta name="Rg-Request-Token" id="Rg-Request-Token" content="aad-">
#     <meta http-equiv="expires" content="0">
#     <link rel="preload" as="script" href="https://c5.rgstatic.net/m/42673493869132589/javascript/lite/lite.js" crossOrigin="1">        <link rel="icon" type="image/png" href="https://c5.rgstatic.net/m/41542880220916/images/favicon/favicon-32x32.png" sizes="32x32">
#     <link rel="icon" type="image/png" href="https://www.researchgate.net/favicon-96x96.png" sizes="96x96">
#     <link rel="icon" type="image/png" href="https://c5.rgstatic.net/m/42134677640462/images/favicon/favicon-16x16.png" sizes="16x16">
#     <link rel="shortcut icon" type="image/x-icon" href="https://c5.rgstatic.net/m/426351313275430/images/favicon/favicon.ico">
#     <link rel="mask-icon" href="https://c5.rgstatic.net/m/441272785461785/images/favicon/favicon.svg" color="#00ccbb">    <link rel="manifest" href="https://www.researchgate.net/manifest.json">
#     <meta name="application-name" content="ResearchGate">
#     <meta name="msapplication-TileColor" content="#00ccbb">    <meta name="msapplication-TileImage" content="https://www.researchgate.net/mstile-144x144.png">
#     <meta name="theme-color" content="#444444">     <link rel="search" type="application/opensearchdescription+xml" title="ResearchGate search" href="https://www.researchgate.net/application.DownloadOpenSearchPlugin.html">
#     <link rel="meta" type="application/rdf+xml" title="ICRA labels" href="https://www.researchgate.net/application.DownloadLabels.html">
#     <link rel="http://oexchange.org/spec/0.8/rel/related-target" type="application/xrd+xml" href="https://www.researchgate.net/application.DownloadOExchange.html">
#     <base href="https://www.researchgate.net/"/>
#     <script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">var pageConfig={"module":"lite","action":"lite.PublicationDetails","product":"application","stylesHome":"https:\/\/c5.rgstatic.net\/m\/","staticHost":"https:\/\/c5.rgstatic.net","yuiDisabled":true,"longRunningRequestIdentifier":"LongRunningRequest.lite.PublicationDetails","longRunningRequestFp":"72b825cfd06b891b98628b96f2fb7028d123ac29","platformFeatures":{"nova":[],"rigel":{"useRigelForgeryOverlay":false},"react":{"propTypesStrictMode":false}},"isLitePage":true,"applicationVersionTag":"v354.18.0"};var requestConfig={"correlationId":"rgreq-dababd9835d483876c381295ad4465a6","isLoggedIn":false};window.rootUrl="https://www.researchgate.net/";</script>
#     <script id="Rg-Request-Cache-Config" nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">var requestCachedConfig={"isCachedPage":false,"continent":"Europe","country":"ES","isEu":true,"isMobile":false,"isCrawler":false,"logExtendedRequest":true,"logTimeToFirstAd":true,"flag":"cloudflare","fingerprint":"feb764a455f984d629ff72466d2aec41e9f56166"};</script>
#         <style>
#         .qc-cmp-ui .qc-cmp-arrow-down {
#             background: url("data:image/svg+xml;charset=utf-8,%3Csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 16 16' fill='none' stroke='%230080ff' stroke-width='2' stroke-linecap='round' stroke-linejoin='round'%3E%3Cpath d='M2 5l6 6 6-6'/%3E%3C/svg%3E") 50% no-repeat !important;
#         }
#     </style>
#     <script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">
#         window.quantcastVersion=2;
#         window.quantcastEnabled=true;
#         var __wd=["https://www.researchgate.net/", "https://c5.rgstatic.net/", "https://quantcast.mgr.consensu.org", "https://static.quantcast.mgr.consensu.org"];(function(d,l){function m(){if(!d.quantcastEnabled)return!1;var b;if(b=/^(.*;)?\s*disable_quantcast\s*=/.test(l.cookie))b=/^(.*;)?\s*disable_quantcast\s*=(\s*[^;]*)/.exec(l.cookie),b="1"===(b&&b[2]||"");return b?!1:!0}function g(b,e){return e.some(function(c){return 0===b.indexOf(c)})}var n=!1,h=[],p=[],k=["appendChild","insertBefore","replaceChild"];if(m())for(var f=0;f<k.length;f++)Element.prototype[k[f]]=function(b){var e=Element.prototype[b];return function(){var c;if(c=0<arguments.length){c=
#             arguments;var a;if(a=0<c.length&&c[0].tagName&&-1!==["script","iframe","link","style"].indexOf(c[0].tagName.toLowerCase()))a=c[0],a.src||a.href?(a=a.src||a.href,g(a,d.__wd)&&-1===a.indexOf("/delivery/manager.js")?a=!0:(a=g(a,p),a=n&&!a)):a=!0,a=!a;a?(h.push({s:this,m:b,a:c}),c=!0):c=!1}if(!c)return e.apply(this,arguments)}}(k[f]);d.loadDeferredObjects=function(b){b=b||[];n=!0;p=b;var e=[];h.forEach(function(c){var a=c.a[0];g(a.src||a.href,b)?e.push(c):Element.prototype[c.m].apply(c.s,c.a)});h=e};
#             d.canAskForCookieConsent=m;d.__headerTagQueue=[];d.headerTagLoaded=function(b){d.__headerTagQueue.push(b)}})(window,document);</script>
#     <noscript></noscript><meta property="twitter:site" content="@ResearchGate">
# <meta property="twitter:creator" content="@ResearchGate">
# <meta property="twitter:card" content="summary">
# <meta property="twitter:url" content="https://www.researchgate.net/publication/295548023_Geneva_Water_Actors">
# <meta property="og:site" content="ResearchGate">
# <meta property="og:site_name" content="ResearchGate">
# <meta property="og:type" content="website">
# <meta property="og:title" content="(PDF) Geneva Water Actors">
# <meta property="og:description" content="PDF | The database leading to the following visuals aims at characterizing the main actors of the “Geneva international” in the water sector. As of... | Find, read and cite all the research you need on ResearchGate">
# <meta property="og:url" content="https://www.researchgate.net/publication/295548023_Geneva_Water_Actors">
# <meta property="og:image" content="https://i1.rgstatic.net/publication/295548023_Geneva_Water_Actors/links/56cb315408aee3cee54160e9/largepreview.png">
# <meta property="gs_meta_revision" content="1.1">
# <meta property="citation_title" content="Geneva Water Actors">
# <meta property="citation_abstract_html_url" content="https://www.researchgate.net/publication/295548023_Geneva_Water_Actors">
# <meta property="citation_fulltext_html_url" content="https://www.researchgate.net/publication/295548023_Geneva_Water_Actors">
# <meta property="citation_author" content="Geneva Water Hub">
# <meta property="citation_publication_date" content="2015/01/01">
# <meta property="citation_doi" content="10.13140/RG.2.1.4785.1282">
# <meta property="citation_pdf_url" content="https://www.researchgate.net/profile/Geneva_Water_Hub/publication/295548023_Geneva_Water_Actors/links/56cb315408aee3cee54160e9/Geneva-Water-Actors.pdf">
# <meta property="DC.identifier" content="http://dx.doi.org/10.13140/RG.2.1.4785.1282">
# <meta property="rg:id" content="PB:295548023">
# <link rel="canonical" href="https://www.researchgate.net/publication/295548023_Geneva_Water_Actors">
# <link rel="dns-prefetch" href="https://c5.rgstatic.net">
# <link rel="dns-prefetch" href="https://i1.rgstatic.net">
# <link rel="preconnect" href="https://securepubads.g.doubleclick.net">
# <link rel="preconnect" href="https://www.google-analytics.com">
# <link rel="preconnect" href="https://tags.crwdcntrl.net">
# <meta name="viewport" content="width=device-width,initial-scale=1">
# <meta name="robots" content="noarchive">
# <script type="application/ld+json">{"@context":"https:\/\/schema.org\/","@type":"ScholarlyArticle","datePublished":"2015-01-01","headline":"Geneva Water Actors","mainEntityOfPage":"https:\/\/www.researchgate.net\/publication\/295548023_Geneva_Water_Actors","image":"https:\/\/i1.rgstatic.net\/publication\/295548023_Geneva_Water_Actors\/links\/56cb315408aee3cee54160e9\/largepreview.png","author":[{"@context":"https:\/\/schema.org\/","@type":"Person","name":"Geneva Water Hub","url":"https:\/\/www.researchgate.net\/profile\/Geneva_Water_Hub","image":"https:\/\/i1.rgstatic.net\/ii\/profile.image\/281315485208576-1444082246024_Q64\/Geneva_Water_Hub.jpg","memberOf":{"@context":"https:\/\/schema.org\/","@type":"Organization","name":"University of Geneva"}}],"publisher":{"@context":"https:\/\/schema.org\/","@type":"Organization","name":"unknown","url":"unknown","logo":"unknown"}}</script>
# <script src="https://c5.rgstatic.net/javascript/header/load.js" async></script>
#     <!-- TradeDoubler site verification 2966599 -->
# <style>.nova-e-icon{width:1em;height:1em;vertical-align:-.1875rem;display:inline-block;overflow:visible}.nova-e-icon{position:relative;fill:currentColor}.nova-e-icon--size-s{width:1rem;height:1rem}.nova-e-icon--size-m{width:1.5rem;height:1.5rem}.nova-e-icon--color-green.nova-e-icon--theme-bare.nova-e-icon--luminosity-medium{color:#00a39e}.nova-e-icon--color-green.nova-e-icon--theme-bare.nova-e-icon--luminosity-low{color:#00141a}.nova-e-icon--color-grey.nova-e-icon--theme-bare.nova-e-icon--luminosity-medium{color:#888}.nova-e-icon--color-grey.nova-e-icon--theme-bare.nova-e-icon--luminosity-low{color:#333}.nova-e-icon--color-white.nova-e-icon--theme-bare.nova-e-icon--luminosity-low,.nova-e-icon--color-white.nova-e-icon--theme-bare.nova-e-icon--luminosity-medium{color:#fff}.nova-e-text{margin-top:0;color:inherit;font-weight:400;font-family:Roboto,Arial,sans-serif;font-size:.875rem;line-height:1.3;margin-bottom:1.42857em}@media screen and (min-width:0px){.nova-e-text--size-s{font-size:.75rem}.nova-e-text--size-l,.nova-e-text--size-m{font-size:.875rem}.nova-e-text--size-xl{font-size:1.1875rem}.nova-e-text--size-xxl{font-size:1.375rem}}@media screen and (min-width:992px){.nova-e-text--size-s{font-size:.75rem}.nova-e-text--size-m{font-size:.875rem}.nova-e-text--size-l{font-size:1rem}.nova-e-text--size-xl{font-size:1.375rem}.nova-e-text--size-xxl{font-size:1.75rem}}.nova-e-text--clamp{overflow:hidden;white-space:nowrap;text-overflow:ellipsis}.nova-e-text[class*=nova-e-text--clamp-]{overflow:hidden;display:block;display:-webkit-box;text-overflow:ellipsis;text-overflow:-o-ellipsis-lastline;-webkit-box-orient:vertical;text-align:left}@-moz-document url-prefix(""){.nova-e-text[class*=nova-e-text--clamp-]{padding-right:1em;position:relative}.nova-e-text[class*=nova-e-text--clamp-]:before{position:absolute;right:0;bottom:0}.nova-e-text[class*=nova-e-text--clamp-]:after{position:absolute;right:0;width:1em;background:#fff}}.nova-e-text--size-s{margin-bottom:1.25em}.nova-e-text--size-l{margin-bottom:1.25em}.nova-e-text--size-xl{line-height:1.2;margin-bottom:.90909em}.nova-e-text--size-xxl{line-height:1.2;margin-bottom:.89286em}.nova-e-text--spacing-none{margin-bottom:0}.nova-e-text--spacing-xxs{margin-bottom:5px}.nova-e-text--spacing-xs{margin-bottom:10px}.nova-e-text--spacing-s{margin-bottom:15px}.nova-e-text--spacing-m{margin-bottom:20px}.nova-e-text--color-white,.nova-e-text--color-white:hover{color:#fff}.nova-e-text--color-grey-500,.nova-e-text--color-grey-500:hover{color:#888}.nova-e-text--color-grey-600,.nova-e-text--color-grey-600:hover{color:#777}.nova-e-text--color-grey-700,.nova-e-text--color-grey-700:hover{color:#555}.nova-e-text--color-grey-800,.nova-e-text--color-grey-800:hover{color:#333}.nova-e-text--color-grey-900,.nova-e-text--color-grey-900:hover{color:#111}.nova-e-text--color-inherit{color:inherit}.nova-c-button-group{display:-webkit-inline-box;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-collapse:separate}.nova-c-button-group--gutter-m{margin-left:-20px;margin-bottom:-20px}@-webkit-keyframes fadeFocus{to{-webkit-box-shadow:0 0 0 1px transparent;box-shadow:0 0 0 1px transparent}}@keyframes fadeFocus{to{-webkit-box-shadow:0 0 0 1px transparent;box-shadow:0 0 0 1px transparent}}@-webkit-keyframes fadeFocusBare{to{-webkit-box-shadow:0 2px 0 0 transparent;box-shadow:0 2px 0 0 transparent;background:transparent}}@keyframes fadeFocusBare{to{-webkit-box-shadow:0 2px 0 0 transparent;box-shadow:0 2px 0 0 transparent;background:transparent}}button::-moz-focus-inner,input[type=button]::-moz-focus-inner{border:0;padding:0;margin-top:-.4px;margin-bottom:-.4px}.nova-c-button{-webkit-box-sizing:border-box;box-sizing:border-box;font-family:Roboto,Arial,sans-serif;border:1px solid transparent;outline:none;background-color:transparent;cursor:pointer;text-decoration:none;position:relative;text-align:center;line-height:1;overflow:hidden;margin:0;vertical-align:top;displa ...
# <title>(PDF) Geneva Water Actors</title>
# <meta name="description" content="PDF | The database leading to the following visuals aims at characterizing the main actors of the &ldquo;Geneva international&rdquo; in the water sector. As of... | Find, read and cite all the research you need on ResearchGate"/>
# </head><body>
# <div id="lite-page" class="lite-page lite-page--grey-wide publication"><div class="lite-page__above"><div id="lite-ad-32u2d7z1byv" class="lite-page-ad lite-page-ad--vertical-spacing-xs lite-page-ad--layout-header lite-page-ad--has-label lite-page-ad--empty js-lite-sticky"><div class="lite-page-ad__inner js-lite-sticky-target"><button class="nova-c-button nova-c-button--align-left nova-c-button--radius-m nova-c-button--size-m nova-c-button--color-grey nova-c-button--theme-bare nova-c-button--width-square lite-page-ad__header-close" type="button" id="lite-ad-32u2d7z1byv-close"><svg aria-hidden="true" class="nova-e-icon nova-e-icon--size-s nova-e-icon--theme-bare nova-e-icon--color-inherit nova-e-icon--luminosity-medium nova-c-button__icon"><use xlink:href="/m/454327524547536/images/icons/nova/icon-stack-s.svg#close-circle-s"></use></svg></button><script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">document.querySelector('#lite-ad-32u2d7z1byv-close').onclick = function(e) {document.querySelector('#lite-ad-32u2d7z1byv').style.display = 'none'; RGDom.className.addClass(document.querySelector('#lite-page'), 'lite-page--header-ad-collapsed');};</script><div id="32u2d7z1byv"><rg-ad id="uyvse47ptb" ad-unit="LoggedOut_PublicationWithFulltext_Top" ad-unit-path="/83500759/LoggedOut_PublicationWithFulltext_Top" ad-location="Top" refresh-timeout="-1" load-on-init="false" collapse="never" class="rg-ad" ad-unit-sizes="[[728,90],[970,90],&quot;fluid&quot;]" targeting-variants="prd,lite-page" targeting-snippet_id="uyvse47ptb" targeting-sequence="1"><rg-ad-size size="[728,90]"></rg-ad-size><rg-ad-size size="[970,90]"></rg-ad-size><rg-ad-size size="&quot;fluid&quot;"></rg-ad-size><rg-ad-sizeset viewport-size="[0,0]" slot-sizes="[]"></rg-ad-sizeset><rg-ad-sizeset viewport-size="[728,0]" slot-sizes="[[728,90],&quot;fluid&quot;]"></rg-ad-sizeset><rg-ad-sizeset viewport-size="[970,0]" slot-sizes="[[970,90],[728,90],&quot;fluid&quot;]"></rg-ad-sizeset></rg-ad><script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">document.getElementById("uyvse47ptb").addEventListener('adUnitEvent', function(event){if(event.detail.type==="slotRenderEnded"){ if(event.detail.gptEvent.isEmpty){document.querySelector('#lite-ad-32u2d7z1byv').classList.remove('lite-page-ad--rendered');var elem=document.querySelector("#lite-ad-32u2d7z1byv");elem && elem.classList.add('lite-page-ad--empty');}else{document.querySelector('#lite-ad-32u2d7z1byv').classList.add('lite-page-ad--rendered');var elem=document.querySelector("#lite-ad-32u2d7z1byv");elem && elem.classList.remove('lite-page-ad--empty');}}})</script></div></div></div></div><main class="lite-page__main" role="main"><section class="lite-page__content"><section class="research-detail-header-section"><span class="nova-e-badge nova-e-badge--color-green nova-e-badge--display-inline nova-e-badge--luminosity-high nova-e-badge--size-l nova-e-badge--theme-solid nova-e-badge--radius-m research-detail-header-section__badge" data-testid="research-meta-type">Technical Report</span><span class="nova-e-badge nova-e-badge--color-green nova-e-badge--display-inline nova-e-badge--luminosity-medium nova-e-badge--size-l nova-e-badge--theme-ghost nova-e-badge--radius-m research-detail-header-section__badge">PDF Available</span><div class="research-detail-header-section__flex-container"><div class="research-detail-header-section__ie11"><h1 class="nova-e-text nova-e-text--size-xl nova-e-text--family-sans-serif nova-e-text--spacing-none nova-e-text--color-grey-900 research-detail-header-section__title">Geneva Water Actors</h1><div class="research-detail-header-section__metadata"><div class="nova-e-text nova-e-text--size-m nova-e-text--family-sans-serif nova-e-text--spacing-xxs nova-e-text--color-grey-700"><ul class="nova-e-list nova-e-list--size-m nova-e-list--type-inline nova-e-list--spacing-none"><li class="nova-e-list__item">January 2015</li></ul></div><div class="nova-e-text nova-e-text--size-m nova-e-text--family-sans-serif nova-e-text--spacing-xxs nova-e ...
#                     <style type="text/css" media="">
#                 @font-face{font-display:swap;font-family:ff4;src:url(https://i1.rgstatic.net/ii/fonts/pdftohtml/8a67d3ccb3b49137c64b5866692e2f06.woff?p=4&ak=331960720347141-1456157011985)format("woff");}@font-face{font-display:swap;font-family:ff3;src:url(https://i1.rgstatic.net/ii/fonts/pdftohtml/f3078a381b89b89256e08082b0886388.woff?p=3&ak=331960720347141-1456157011985)format("woff");}@font-face{font-display:swap;font-family:ff2;src:url(https://i1.rgstatic.net/ii/fonts/pdftohtml/ccfa4d2595a80583f6c49665dcd0fa86.woff?p=2&ak=331960720347141-1456157011985)format("woff");}@font-face{font-display:swap;font-family:ff1;src:url(https://i1.rgstatic.net/ii/fonts/pdftohtml/6de836edec2dc6fef56bed340c7298fb.woff?p=1&ak=331960720347141-1456157011985)format("woff");}            </style>
#             <script type="application/javascript">window.addEventListener("load", function () {[].slice.call(document.querySelectorAll("#pdf-html-reader style")).forEach(function (a) {a.media = "all"})});</script>
#
#         <style type="text/css" media="all">
#             @media only screen and (min-width: 280px) and (max-width: 329px){.pc{transform: scale(0.25);}.pf{width: 240px !important; height: 173px !important;}}
# @media only screen and (min-width: 330px) and (max-width: 379px){.pc{transform: scale(0.31);}.pf{width: 298px !important; height: 215px !important;}}
# @media only screen and (min-width: 380px) and (max-width: 429px){.pc{transform: scale(0.36);}.pf{width: 346px !important; height: 250px !important;}}
# @media only screen and (min-width: 430px) and (max-width: 479px){.pc{transform: scale(0.41);}.pf{width: 394px !important; height: 284px !important;}}
# @media only screen and (min-width: 480px) and (max-width: 529px){.pc{transform: scale(0.46);}.pf{width: 442px !important; height: 319px !important;}}
# @media only screen and (min-width: 530px) and (max-width: 579px){.pc{transform: scale(0.51);}.pf{width: 490px !important; height: 353px !important;}}
# @media only screen and (min-width: 580px) and (max-width: 629px){.pc{transform: scale(0.57);}.pf{width: 548px !important; height: 395px !important;}}
# @media only screen and (min-width: 630px) and (max-width: 679px){.pc{transform: scale(0.62);}.pf{width: 596px !important; height: 430px !important;}}
# @media only screen and (min-width: 680px) and (max-width: 729px){.pc{transform: scale(0.67);}.pf{width: 644px !important; height: 464px !important;}}
# @media only screen and (min-width: 730px) and (max-width: 779px){.pc{transform: scale(0.72);}.pf{width: 692px !important; height: 499px !important;}}
# @media only screen and (min-width: 780px) and (max-width: 829px){.pc{transform: scale(0.77);}.pf{width: 740px !important; height: 533px !important;}}
# @media only screen and (min-width: 830px) and (max-width: 879px){.pc{transform: scale(0.83);}.pf{width: 797px !important; height: 575px !important;}}
# @media only screen and (min-width: 880px) and (max-width: 929px){.pc{transform: scale(0.88);}.pf{width: 845px !important; height: 609px !important;}}
# @media only screen and (min-width: 930px) and (max-width: 979px){.pc{transform: scale(0.93);}.pf{width: 893px !important; height: 644px !important;}}
# @media only screen and (min-width: 980px) and (max-width: 991px){.pc{transform: scale(0.98);}.pf{width: 941px !important; height: 679px !important;}}
# @media only screen and (min-width: 992px) and (max-width: 1041px){.pc{transform: scale(0.41);}.pf{width: 394px !important; height: 284px !important;}}
# @media only screen and (min-width: 1042px) and (max-width: 1091px){.pc{transform: scale(0.46);}.pf{width: 442px !important; height: 319px !important;}}
# @media only screen and (min-width: 1092px) and (max-width: 1141px){.pc{transform: scale(0.51);}.pf{width: 490px !important; height: 353px !important;}}
# @media only screen and (min-width: 1142px) and (max-width: 1191px){.pc{transform: scale(0.56);}.pf{width: 538px !important; height: 388px !important;}}
# @media only screen and (min-width: 1192px) and (max-width: 1241px){.pc{transform: scale(0.61);}.pf{width: 586px !important; height: 423px !important;}}
# @media only screen and (min-width: 1242px) and (max-width: 1291px){.pc{transform: scale(0.67);}.pf{width: 644px !important; height: 464px !important;}}
# @media only screen and (min-width: 1292px) and (max-width: 1341px){.pc{transform: scale(0.72);}.pf{width: 692px !important; height: 499px !important;}}
# @media only screen and (min-width: 1342px) and (max-width: 1391px){.pc{transform: scale(0.77);}.pf{width: 740px !important; height: 533px !important;}}
# @media only screen and (min-width: 1392px) and (max-width: 1441px){.pc{transform: scale(0.82);}.pf{width: 788px !important; height: 568px !important;}}
# @media only screen and (min-width: 1442px) and (max-width: 1491px){.pc{transform: scale(0.87);}.pf{width: 836px !important; height: 603px !important;}}
# @media only screen and (min-width: 1492px) and (max-width: 1541px){.pc{transform: scale(0.93);}.pf{width: 893px !important; height: 644px !important;}}
# @media only screen and (min-width: 1542px) and (max-width: 1557px){.pc{transform: scale(0.98);}.pf{width: 941px !important; height: 679px !important;}}
# @media only screen and (min-width: 1473px) and (max-width: 1980px){.pc{transform: scale(0.88);}.pf{width: 845px !important; height: 609px !important;}}
# @media only screen and (max-width: 280px) {.pdf-html-reader {display: none !important;}}
# .ff0{font-family:sans-serif;visibility:hidden;}
# .ff1{font-family:ff1;line-height:0.885000;font-style:normal;font-weight:normal;visibility:visible;}
# .ff2{font-family:ff2;line-height:0.888000;font-style:normal;font-weight:normal;visibility:visible;}
# .ff3{font-family:ff3;line-height:0.739000;font-style:normal;font-weight:normal;visibility:visible;}
# .ff4{font-family:ff4;line-height:0.756000;font-style:normal;font-weight:normal;visibility:visible;}
# .m2{transform:matrix(0.169351,-0.116776,0.116776,0.169351,0,0);-ms-transform:matrix(0.169351,-0.116776,0.116776,0.169351,0,0);-webkit-transform:matrix(0.169351,-0.116776,0.116776,0.169351,0,0);}
# .m3{transform:matrix(0.178123,-0.102901,0.102901,0.178123,0,0);-ms-transform:matrix(0.178123,-0.102901,0.102901,0.178123,0,0);-webkit-transform:matrix(0.178123,-0.102901,0.102901,0.178123,0,0);}
# .mb{transform:matrix(0.182657,-0.094619,0.094619,0.182657,0,0);-ms-transform:matrix(0.182657,-0.094619,0.094619,0.182657,0,0);-webkit-transform:matrix(0.182657,-0.094619,0.094619,0.182657,0,0);}
# .m4{transform:matrix(0.186019,-0.087825,0.087825,0.186019,0,0);-ms-transform:matrix(0.186019,-0.087825,0.087825,0.186019,0,0);-webkit-transform:matrix(0.186019,-0.087825,0.087825,0.186019,0,0);}
# .m5{transform:matrix(0.191834,-0.074271,0.074271,0.191834,0,0);-ms-transform:matrix(0.191834,-0.074271,0.074271,0.191834,0,0);-webkit-transform:matrix(0.191834,-0.074271,0.074271,0.191834,0,0);}
# .m6{transform:matrix(0.196350,-0.061345,0.061345,0.196350,0,0);-ms-transform:matrix(0.196350,-0.061345,0.061345,0.196350,0,0);-webkit-transform:matrix(0.196350,-0.061345,0.061345,0.196350,0,0);}
# .m7{transform:matrix(0.200454,-0.046202,0.046202,0.200454,0,0);-ms-transform:matrix(0.200454,-0.046202,0.046202,0.200454,0,0);-webkit-transform:matrix(0.200454,-0.046202,0.046202,0.200454,0,0);}
# .m8{transform:matrix(0.203703,-0.028660,0.028660,0.203703,0,0);-ms-transform:matrix(0.203703,-0.028660,0.028660,0.203703,0,0);-webkit-transform:matrix(0.203703,-0.028660,0.028660,0.203703,0,0);}
# .m9{transform:matrix(0.205443,-0.010460,0.010460,0.205443,0,0);-ms-transform:matrix(0.205443,-0.010460,0.010460,0.205443,0,0);-webkit-transform:matrix(0.205443,-0.010460,0.010460,0.205443,0,0);}
# .ma{transform:matrix(0.205582,0.007235,-0.007235,0.205582,0,0);-ms-transform:matrix(0.205582,0.007235,-0.007235,0.205582,0,0);-webkit-transform:matrix(0.205582,0.007235,-0.007235,0.205582,0,0);}
# .m0{transform:matrix(0.205691,0.000000,0.000000,0.205709,0,0);-ms-transform:matrix(0.205691,0.000000,0.000000,0.205709,0,0);-webkit-transform:matrix(0.205691,0.000000,0.000000,0.205709,0,0);}
# .m1{transform:matrix(0.205709,0.000000,0.000000,0.205709,0,0);-ms-transform:matrix(0.205709,0.000000,0.000000,0.205709,0,0);-webkit-transform:matrix(0.205709,0.000000,0.000000,0.205709,0,0);}
# .v0{vertical-align:0.000000px;}
# .ls35{letter-spacing:-1.920000px;}
# .lsf{letter-spacing:-1.767798px;}
# .lsd{letter-spacing:-1.571376px;}
# .ls2f{letter-spacing:-0.800000px;}
# .ls34{letter-spacing:-0.638400px;}
# .ls16{letter-spacing:-0.589266px;}
# .ls14{letter-spacing:-0.392844px;}
# .ls2a{letter-spacing:-0.360000px;}
# .ls12{letter-spacing:-0.345703px;}
# .ls25{letter-spacing:-0.320000px;}
# .ls32{letter-spacing:-0.308000px;}
# .ls10{letter-spacing:-0.098211px;}
# .ls15{letter-spacing:-0.078569px;}
# .ls26{letter-spacing:-0.057250px;}
# .ls18{letter-spacing:-0.051070px;}
# .ls11{letter-spacing:-0.039284px;}
# .ls2d{letter-spacing:-0.038400px;}
# .ls2e{letter-spacing:-0.032000px;}
# .ls19{letter-spacing:-0.031428px;}
# .ls31{letter-spacing:-0.026400px;}
# .ls30{letter-spacing:-0.025600px;}
# .ls28{letter-spacing:-0.024000px;}
# .ls17{letter-spacing:-0.023571px;}
# .ls1f{letter-spacing:-0.020000px;}
# .ls27{letter-spacing:-0.017175px;}
# .ls1e{letter-spacing:-0.016000px;}
# .ls13{letter-spacing:-0.015714px;}
# .ls20{letter-spacing:-0.012800px;}
# .ls38{letter-spacing:-0.012000px;}
# .ls23{letter-spacing:-0.009600px;}
# .ls1d{letter-spacing:-0.008000px;}
# .ls36{letter-spacing:-0.007200px;}
# .ls21{letter-spacing:-0.006400px;}
# .ls39{letter-spacing:-0.004800px;}
# .ls1c{letter-spacing:-0.004000px;}
# .ls22{letter-spacing:-0.003200px;}
# .ls37{letter-spacing:-0.002400px;}
# .lse{letter-spacing:0.000000px;}
# .ls9{letter-spacing:0.003200px;}
# .ls8{letter-spacing:0.009600px;}
# .ls1{letter-spacing:0.023571px;}
# .lsc{letter-spacing:0.024000px;}
# .lsb{letter-spacing:0.034350px;}
# .ls29{letter-spacing:0.040000px;}
# .ls2{letter-spacing:0.051070px;}
# .lsa{letter-spacing:0.057250px;}
# .ls3{letter-spacing:0.098211px;}
# .ls24{letter-spacing:0.320000px;}
# .ls0{letter-spacing:0.392844px;}
# .ls1b{letter-spacing:0.396000px;}
# .ls2c{letter-spacing:0.400000px;}
# .ls2b{letter-spacing:0.800000px;}
# .ls33{letter-spacing:1.542800px;}
# .ls6{letter-spacing:3.180798px;}
# .ls7{letter-spacing:3.199998px;}
# .ls4{letter-spacing:6.399995px;}
# .ls5{letter-spacing:6.409595px;}
# .ls1a{letter-spacing:56.569440px;}
# .sc_{text-shadow:none;}
# .sc0{text-shadow:-0.015em 0 transparent,0 0.015em transparent,0.015em 0 transparent,0 -0.015em  transparent;}
# @media screen and (-webkit-min-device-pixel-ratio:0){
# .sc_{-webkit-text-stroke:0px transparent;}
# .sc0{-webkit-text-stroke:0.015em transparent;text-shadow:none;}
# }
# .ws18{word-spacing:-19.448000px;}
# .ws19{word-spacing:-14.360800px;}
# .wsd{word-spacing:-13.481590px;}
# .wsc{word-spacing:-13.471990px;}
# .ws16{word-spacing:-12.160000px;}
# .ws12{word-spacing:-10.934750px;}
# .ws11{word-spacing:-10.877500px;}
# .wse{word-spacing:-10.252792px;}
# .ws10{word-spacing:-8.840000px;}
# .ws14{word-spacing:-8.000000px;}
# .ws8{word-spacing:-7.996000px;}
# .ws3{word-spacing:-7.856880px;}
# .ws13{word-spacing:-7.624000px;}
# .wsa{word-spacing:-7.600000px;}
# .ws9{word-spacing:-7.596000px;}
# .wsb{word-spacing:-7.580000px;}
# .ws7{word-spacing:-7.562247px;}
# .ws6{word-spacing:-7.515106px;}
# .ws2{word-spacing:-7.464036px;}
# .ws1{word-spacing:-7.118333px;}
# .ws4{word-spacing:-7.071192px;}
# .ws5{word-spacing:-6.874770px;}
# .ws0{word-spacing:-5.696238px;}
# .ws1a{word-spacing:-4.548000px;}
# .ws2a{word-spacing:-1.142400px;}
# .ws28{word-spacing:-0.716800px;}
# .ws37{word-spacing:-0.480000px;}
# .ws1e{word-spacing:-0.396772px;}
# .ws15{word-spacing:-0.040000px;}
# .ws31{word-spacing:-0.034350px;}
# .ws17{word-spacing:-0.032000px;}
# .ws1d{word-spacing:-0.023571px;}
# .ws25{word-spacing:-0.009600px;}
# .ws21{word-spacing:-0.004000px;}
# .ws24{word-spacing:-0.003200px;}
# .ws39{word-spacing:-0.002400px;}
# .ws1b{word-spacing:0.000000px;}
# .ws3b{word-spacing:0.002400px;}
# .ws33{word-spacing:0.003200px;}
# .ws20{word-spacing:0.004000px;}
# .ws3a{word-spacing:0.004800px;}
# .ws23{word-spacing:0.008000px;}
# .ws2f{word-spacing:0.009600px;}
# .ws22{word-spacing:0.012000px;}
# .ws32{word-spacing:0.012800px;}
# .ws1c{word-spacing:0.015714px;}
# .ws30{word-spacing:0.017175px;}
# .ws35{word-spacing:0.026400px;}
# .ws34{word-spacing:0.038400px;}
# .ws36{word-spacing:0.308000px;}
# .ws1f{word-spacing:0.341774px;}
# .ws38{word-spacing:0.801600px;}
# .ws2e{word-spacing:3.001600px;}
# .ws26{word-spacing:3.529600px;}
# .ws2b{word-spacing:3.660800px;}
# .ws29{word-spacing:3.878400px;}
# .ws2d{word-spacing:3.952000px;}
# .ws2c{word-spacing:4.140800px;}
# .ws27{word-spacing:6.736000px;}
# .wsf{word-spacing:55.856000px;}
# ._b{margin-left:-1220.137600px;}
# ._5{margin-left:-398.236000px;}
# ._6{margin-left:-340.516000px;}
# ._0{margin-left:-266.592000px;}
# ._1{margin-left:-263.232000px;}
# ._7{margin-left:-257.396000px;}
# ._2{margin-left:-245.224000px;}
# ._8{margin-left:-229.404000px;}
# ._9{margin-left:-216.448000px;}
# ._a{margin-left:-81.056000px;}
# ._3{margin-left:-3.209600px;}
# ._c{width:3.100800px;}
# ._4{width:425.395200px;}
# .fc8{color:rgb(255,255,255);}
# .fc7{color:rgb(53,98,140);}
# .fc9{color:rgb(1,2,2);}
# .fc6{color:rgb(0,155,223);}
# .fc5{color:rgb(9,150,136);}
# .fc4{color:rgb(181,81,148);}
# .fc0{color:rgb(35,31,32);}
# .fc2{color:rgb(142,120,44);}
# .fc1{color:rgb(145,204,240);}
# .fc3{color:rgb(208,171,47);}
# .fs1a{font-size:24.000000px;}
# .fsd{font-size:31.999976px;}
# .fsc{font-size:32.000000px;}
# .fs0{font-size:39.284400px;}
# .fs9{font-size:39.284422px;}
# .fs7{font-size:39.284456px;}
# .fs2{font-size:39.284589px;}
# .fs4{font-size:39.284641px;}
# .fs5{font-size:39.284642px;}
# .fs3{font-size:39.284668px;}
# .fs6{font-size:39.284678px;}
# .fsa{font-size:39.284702px;}
# .fs8{font-size:39.284735px;}
# .fsb{font-size:40.000000px;}
# .fs1{font-size:47.141200px;}
# .fse{font-size:48.000000px;}
# .fs10{font-size:56.000000px;}
# .fs12{font-size:57.250000px;}
# .fs19{font-size:58.000000px;}
# .fs15{font-size:64.000000px;}
# .fs13{font-size:72.000000px;}
# .fsf{font-size:80.000000px;}
# .fs17{font-size:88.000000px;}
# .fs11{font-size:120.000000px;}
# .fs14{font-size:144.000000px;}
# .fs16{font-size:160.000000px;}
# .fs18{font-size:280.000000px;}
# .y0{bottom:4.525609px;}
# .yd1{bottom:8.544349px;}
# .yd0{bottom:14.468783px;}
# .ycf{bottom:20.393709px;}
# .y35{bottom:25.178900px;}
# .yce{bottom:26.318143px;}
# .ycd{bottom:32.243070px;}
# .ycc{bottom:38.166516px;}
# .ycb{bottom:44.090949px;}
# .y34{bottom:47.747641px;}
# .yca{bottom:50.015382px;}
# .yc9{bottom:55.939815px;}
# .y4f{bottom:59.893552px;}
# .y68{bottom:61.481578px;}
# .y16{bottom:63.891209px;}
# .y19{bottom:65.241573px;}
# .y18{bottom:70.665657px;}
# .y67{bottom:71.046229px;}
# .ya{bottom:73.334061px;}
# .y4e{bottom:74.686532px;}
# .y1{bottom:76.867958px;}
# .y17{bottom:77.938714px;}
# .y2c{bottom:78.136692px;}
# .y9{bottom:79.191295px;}
# .y11{bottom:80.348520px;}
# .y7{bottom:80.364682px;}
# .yb2{bottom:88.745542px;}
# .y4d{bottom:89.479513px;}
# .y36{bottom:99.329706px;}
# .yb1{bottom:100.265273px;}
# .y37{bottom:103.805122px;}
# .y38{bottom:108.020521px;}
# .y4c{bottom:108.798925px;}
# .y66{bottom:111.725620px;}
# .y39{bottom:111.737280px;}
# .y3a{bottom:113.891469px;}
# .y3b{bottom:116.128766px;}
# .y3c{bottom:117.863308px;}
# .y40{bottom:118.696706px;}
# .y3d{bottom:119.062183px;}
# .y3e{bottom:119.327960px;}
# .y4b{bottom:124.003325px;}
# .y65{bottom:124.440110px;}
# .y3f{bottom:124.696977px;}
# .y1d{bottom:127.414226px;}
# .y2a{bottom:133.833910px;}
# .y4a{bottom:139.207725px;}
# .y3{bottom:139.582715px;}
# .y24{bottom:140.253595px;}
# .y2d{bottom:144.485407px;}
# .y15{bottom:146.054119px;}
# .y28{bottom:146.673279px;}
# .y10{bottom:147.607321px;}
# .y33{bottom:149.918380px;}
# .yf{bottom:152.527948px;}
# .y2f{bottom:153.019935px;}
# .y21{bottom:153.095388px;}
# .y32{bottom:157.191437px;}
# .y49{bottom:158.526314px;}
# .yb4{bottom:158.544416px;}
# .y27{bottom:158.618871px;}
# .yc{bottom:159.000968px;}
# .y1e{bottom:159.515881px;}
# .y2{bottom:160.910549px;}
# .y64{bottom:162.830000px;}
# .y31{bottom:164.298021px;}
# .y8{bottom:165.384287px;}
# .y25{bottom:165.933949px;}
# .y2e{bottom:166.715908px;}
# .y1b{bottom:168.265226px;}
# .y74{bottom:168.611839px;}
# .y63{bottom:171.130546px;}
# .y30{bottom:171.405413px;}
# .y26{bottom:172.352825px;}
# .yd{bottom:172.527237px;}
# .y48{bottom:173.319295px;}
# .yb3{bottom:173.355500px;}
# .y1a{bottom:175.538282px;}
# .y73{bottom:176.511083px;}
# .yc0{bottom:176.996558px;}
# .y2b{bottom:178.511402px;}
# .y1f{bottom:178.776550px;}
# .y13{bottom:182.540619px;}
# .y72{bottom:184.410327px;}
# .y22{bottom:185.194619px;}
# .y6{bottom:185.268823px;}
# .y47{bottom:188.112275px;}
# .y12{bottom:188.330780px;}
# .y5{bottom:191.587493px;}
# .y1c{bottom:191.615919px;}
# .y71{bottom:192.309572px;}
# .yc1{bottom:192.791755px;}
# .ye{bottom:194.122557px;}
# .y4{bottom:197.906163px;}
# .y20{bottom:198.035604px;}
# .y70{bottom:200.208158px;}
# .y14{bottom:204.434943px;}
# .y23{bottom:204.454480px;}
# .y61{bottom:206.089310px;}
# .y46{bottom:208.253703px;}
# .yb{bottom:210.170152px;}
# .y29{bottom:210.873357px;}
# .y60{bottom:213.330284px;}
# .y57{bottom:213.989871px;}
# .y6f{bottom:216.007305px;}
# .y5f{bottom:220.571916px;}
# .y56{bottom:221.230845px;}
# .y45{bottom:223.253216px;}
# .y6e{bottom:223.906549px;}
# .y5e{bottom:227.812890px;}
# .y55{bottom:228.471819px;}
# .y78{bottom:231.065239px;}
# .y81{bottom:231.394374px;}
# .y6d{bottom:231.805793px;}
# .y5d{bottom:235.053864px;}
# .y54{bottom:235.712793px;}
# .y44{bottom:238.251906px;}
# .y6c{bottom:239.704380px;}
# .y5c{bottom:242.294838px;}
# .y53{bottom:242.953767px;}
# .ybe{bottom:243.904803px;}
# .y6b{bottom:247.604282px;}
# .y5b{bottom:249.535812px;}
# .y52{bottom:250.195399px;}
# .y79{bottom:250.257112px;}
# .y43{bottom:253.250596px;}
# .ybd{bottom:255.424534px;}
# .y6a{bottom:255.503526px;}
# .y5a{bottom:256.777444px;}
# .y51{bottom:257.436373px;}
# .y7a{bottom:261.722865px;}
# .ybf{bottom:262.347893px;}
# .y69{bottom:263.402771px;}
# .y59{bottom:264.018418px;}
# .y50{bottom:264.677347px;}
# .y42{bottom:268.249286px;}
# .ybc{bottom:270.235617px;}
# .y58{bottom:271.259392px;}
# .y7b{bottom:273.189276px;}
# .y62{bottom:281.628631px;}
# .y41{bottom:281.770982px;}
# .y7c{bottom:284.655029px;}
# .y7d{bottom:296.131973px;}
# .y75{bottom:300.285659px;}
# .y7e{bottom:307.597068px;}
# .y7f{bottom:319.063479px;}
# .ya6{bottom:324.586532px;}
# .y80{bottom:330.534499px;}
# .ya5{bottom:334.460588px;}
# .y82{bottom:338.671872px;}
# .y8e{bottom:341.432833px;}
# .ybb{bottom:342.709538px;}
# .ya4{bottom:344.334643px;}
# .y77{bottom:349.201730px;}
# .y8d{bottom:350.484534px;}
# .y8c{bottom:359.535751px;}
# .y76{bottom:360.129018px;}
# .y84{bottom:365.952242px;}
# .yba{bottom:375.623056px;}
# .y83{bottom:380.083661px;}
# .yb9{bottom:387.142788px;}
# .yb8{bottom:397.016843px;}
# .ya2{bottom:412.618673px;}
# .ya1{bottom:422.492729px;}
# .y9e{bottom:429.636608px;}
# .y9c{bottom:430.196961px;}
# .y95{bottom:430.877448px;}
# .y86{bottom:432.834979px;}
# .y9d{bottom:437.647758px;}
# .y9b{bottom:440.071016px;}
# .y8b{bottom:440.195228px;}
# .y94{bottom:445.009689px;}
# .y85{bottom:446.967221px;}
# .y8a{bottom:450.892158px;}
# .y9a{bottom:462.790395px;}
# .y89{bottom:467.348917px;}
# .yb7{bottom:468.421898px;}
# .ya0{bottom:469.410126px;}
# .y99{bottom:472.664450px;}
# .y9f{bottom:477.422099px;}
# .y91{bottom:477.694422px;}
# .y90{bottom:488.391352px;}
# .y93{bottom:489.461864px;}
# .yac{bottom:489.838724px;}
# .y88{bottom:492.736759px;}
# .yab{bottom:499.712779px;}
# .y92{bottom:504.272947px;}
# .y87{bottom:505.079328px;}
# .ya3{bottom:505.356625px;}
# .y8f{bottom:505.670949px;}
# .ya8{bottom:509.908564px;}
# .yb6{bottom:510.047624px;}
# .ya7{bottom:519.782620px;}
# .yb5{bottom:526.175248px;}
# .yaa{bottom:537.137918px;}
# .yb0{bottom:540.433384px;}
# .ya9{bottom:547.011973px;}
# .yaf{bottom:548.332628px;}
# .y97{bottom:555.019832px;}
# .yae{bottom:558.206683px;}
# .y96{bottom:562.919076px;}
# .y98{bottom:570.501528px;}
# .yad{bottom:571.502922px;}
# .yc2{bottom:571.507859px;}
# .yc8{bottom:604.612275px;}
# .yc3{bottom:604.636961px;}
# .yc7{bottom:616.131348px;}
# .yc6{bottom:627.651409px;}
# .yc5{bottom:639.171140px;}
# .yc4{bottom:646.777948px;}
# .h21{height:16.200000px;}
# .h11{height:21.600000px;}
# .hf{height:21.663984px;}
# .hd{height:21.664000px;}
# .h1d{height:23.360000px;}
# .h2{height:26.516970px;}
# .ha{height:26.516985px;}
# .h8{height:26.517008px;}
# .h4{height:26.517097px;}
# .h6{height:26.517132px;}
# .h5{height:26.517151px;}
# .h7{height:26.517158px;}
# .hb{height:26.517174px;}
# .h9{height:26.517196px;}
# .hc{height:27.000000px;}
# .he{height:27.080000px;}
# .h1c{height:29.200000px;}
# .h3{height:31.820310px;}
# .h14{height:32.400000px;}
# .h10{height:32.496000px;}
# .h13{height:37.912000px;}
# .h16{height:38.643750px;}
# .h20{height:39.266000px;}
# .h19{height:43.200000px;}
# .h17{height:43.272000px;}
# .h1b{height:48.600000px;}
# .h12{height:54.160000px;}
# .h1e{height:59.576000px;}
# .h15{height:72.120000px;}
# .h18{height:86.544000px;}
# .h1a{height:96.160000px;}
# .h1f{height:189.560000px;}
# .h1{height:685.424013px;}
# .h0{height:692.829555px;}
# .w1{width:972.594458px;}
# .w0{width:980.000000px;}
# .x0{left:2.879933px;}
# .x49{left:37.349520px;}
# .x48{left:41.066361px;}
# .x4a{left:45.276165px;}
# .x44{left:56.630341px;}
# .x46{left:67.916551px;}
# .x45{left:81.978851px;}
# .x1a{left:87.640470px;}
# .x47{left:94.214123px;}
# .x4b{left:104.532510px;}
# .x13{left:131.300183px;}
# .x15{left:136.011507px;}
# .x12{left:139.056493px;}
# .x11{left:145.708107px;}
# .xf{left:150.313568px;}
# .x10{left:154.734779px;}
# .x14{left:170.372658px;}
# .xa{left:180.432611px;}
# .xe{left:183.571051px;}
# .xb{left:195.205259px;}
# .xd{left:201.719704px;}
# .x8{left:206.404739px;}
# .x4{left:213.460574px;}
# .x2{left:216.582045px;}
# .x43{left:222.218086px;}
# .xc{left:226.585621px;}
# .x42{left:229.729773px;}
# .x1{left:234.220823px;}
# .x9{left:243.135965px;}
# .x3{left:253.719716px;}
# .x31{left:261.665760px;}
# .x33{left:267.098959px;}
# .x7{left:270.955280px;}
# .x3e{left:276.956558px;}
# .x5{left:288.332252px;}
# .x3f{left:292.009555px;}
# .x40{left:306.674996px;}
# .x41{left:322.418354px;}
# .x3b{left:336.078287px;}
# .x3c{left:342.779479px;}
# .x6{left:345.796253px;}
# .x3d{left:353.085525px;}
# .x34{left:359.764500px;}
# .x3a{left:406.959194px;}
# .x17{left:437.425592px;}
# .x4c{left:459.638102px;}
# .x19{left:466.103050px;}
# .x38{left:469.718690px;}
# .x32{left:475.095936px;}
# .x1c{left:480.785038px;}
# .x1d{left:487.585793px;}
# .x16{left:493.032981px;}
# .x1e{left:503.645122px;}
# .x1f{left:509.568732px;}
# .x20{left:517.308346px;}
# .x37{left:521.387976px;}
# .x21{left:525.572930px;}
# .x18{left:531.789699px;}
# .x22{left:535.828783px;}
# .x1b{left:539.751315px;}
# .x23{left:544.682519px;}
# .x39{left:568.471587px;}
# .x2d{left:616.673434px;}
# .x2f{left:620.412239px;}
# .x2e{left:624.710915px;}
# .x36{left:636.550730px;}
# .x25{left:650.991537px;}
# .x26{left:664.347019px;}
# .x28{left:669.184484px;}
# .x27{left:673.471469px;}
# .x2a{left:679.625474px;}
# .x2b{left:684.834039px;}
# .x2c{left:695.152427px;}
# .x29{left:705.586012px;}
# .x53{left:768.199043px;}
# .x4f{left:785.022788px;}
# .x50{left:791.964249px;}
# .x54{left:797.048564px;}
# .x30{left:809.145105px;}
# .x4e{left:818.796007px;}
# .x35{left:847.333837px;}
# .x51{left:863.749619px;}
# .x4d{left:883.908984px;}
# .x52{left:916.641478px;}
# .x24{left:958.523929px;}
# @media print{
# .v0{vertical-align:0.000000pt;}
# .ls35{letter-spacing:-3.111184pt;}
# .lsf{letter-spacing:-2.864554pt;}
# .lsd{letter-spacing:-2.546270pt;}
# .ls2f{letter-spacing:-1.296327pt;}
# .ls34{letter-spacing:-1.034469pt;}
# .ls16{letter-spacing:-0.954851pt;}
# .ls14{letter-spacing:-0.636568pt;}
# .ls2a{letter-spacing:-0.583347pt;}
# .ls12{letter-spacing:-0.560180pt;}
# .ls25{letter-spacing:-0.518531pt;}
# .ls32{letter-spacing:-0.499086pt;}
# .ls10{letter-spacing:-0.159142pt;}
# .ls15{letter-spacing:-0.127314pt;}
# .ls26{letter-spacing:-0.092768pt;}
# .ls18{letter-spacing:-0.082754pt;}
# .ls11{letter-spacing:-0.063657pt;}
# .ls2d{letter-spacing:-0.062224pt;}
# .ls2e{letter-spacing:-0.051853pt;}
# .ls19{letter-spacing:-0.050925pt;}
# .ls31{letter-spacing:-0.042779pt;}
# .ls30{letter-spacing:-0.041482pt;}
# .ls28{letter-spacing:-0.038890pt;}
# .ls17{letter-spacing:-0.038194pt;}
# .ls1f{letter-spacing:-0.032408pt;}
# .ls27{letter-spacing:-0.027831pt;}
# .ls1e{letter-spacing:-0.025927pt;}
# .ls13{letter-spacing:-0.025463pt;}
# .ls20{letter-spacing:-0.020741pt;}
# .ls38{letter-spacing:-0.019445pt;}
# .ls23{letter-spacing:-0.015556pt;}
# .ls1d{letter-spacing:-0.012963pt;}
# .ls36{letter-spacing:-0.011667pt;}
# .ls21{letter-spacing:-0.010371pt;}
# .ls39{letter-spacing:-0.007778pt;}
# .ls1c{letter-spacing:-0.006482pt;}
# .ls22{letter-spacing:-0.005185pt;}
# .ls37{letter-spacing:-0.003889pt;}
# .lse{letter-spacing:0.000000pt;}
# .ls9{letter-spacing:0.005185pt;}
# .ls8{letter-spacing:0.015556pt;}
# .ls1{letter-spacing:0.038194pt;}
# .lsc{letter-spacing:0.038890pt;}
# .lsb{letter-spacing:0.055661pt;}
# .ls29{letter-spacing:0.064816pt;}
# .ls2{letter-spacing:0.082754pt;}
# .lsa{letter-spacing:0.092768pt;}
# .ls3{letter-spacing:0.159142pt;}
# .ls24{letter-spacing:0.518531pt;}
# .ls0{letter-spacing:0.636568pt;}
# .ls1b{letter-spacing:0.641682pt;}
# .ls2c{letter-spacing:0.648163pt;}
# .ls2b{letter-spacing:1.296327pt;}
# .ls33{letter-spacing:2.499966pt;}
# .ls6{letter-spacing:5.154190pt;}
# .ls7{letter-spacing:5.185302pt;}
# .ls4{letter-spacing:10.370604pt;}
# .ls5{letter-spacing:10.386160pt;}
# .ls1a{letter-spacing:91.665582pt;}
# .ws18{word-spacing:-31.513698pt;}
# .ws19{word-spacing:-23.270358pt;}
# .wsd{word-spacing:-21.845678pt;}
# .wsc{word-spacing:-21.830122pt;}
# .ws16{word-spacing:-19.704163pt;}
# .ws12{word-spacing:-17.718758pt;}
# .ws11{word-spacing:-17.625990pt;}
# .wse{word-spacing:-16.613708pt;}
# .ws10{word-spacing:-14.324408pt;}
# .ws14{word-spacing:-12.963265pt;}
# .ws8{word-spacing:-12.956784pt;}
# .ws3{word-spacing:-12.731352pt;}
# .ws13{word-spacing:-12.353992pt;}
# .wsa{word-spacing:-12.315102pt;}
# .ws9{word-spacing:-12.308620pt;}
# .wsb{word-spacing:-12.282694pt;}
# .ws7{word-spacing:-12.253927pt;}
# .ws6{word-spacing:-12.177539pt;}
# .ws2{word-spacing:-12.094785pt;}
# .ws1{word-spacing:-11.534605pt;}
# .ws4{word-spacing:-11.458217pt;}
# .ws5{word-spacing:-11.139933pt;}
# .ws0{word-spacing:-9.230231pt;}
# .ws1a{word-spacing:-7.369616pt;}
# .ws2a{word-spacing:-1.851154pt;}
# .ws28{word-spacing:-1.161509pt;}
# .ws37{word-spacing:-0.777796pt;}
# .ws1e{word-spacing:-0.642933pt;}
# .ws15{word-spacing:-0.064816pt;}
# .ws31{word-spacing:-0.055661pt;}
# .ws17{word-spacing:-0.051853pt;}
# .ws1d{word-spacing:-0.038194pt;}
# .ws25{word-spacing:-0.015556pt;}
# .ws21{word-spacing:-0.006482pt;}
# .ws24{word-spacing:-0.005185pt;}
# .ws39{word-spacing:-0.003889pt;}
# .ws1b{word-spacing:0.000000pt;}
# .ws3b{word-spacing:0.003889pt;}
# .ws33{word-spacing:0.005185pt;}
# .ws20{word-spacing:0.006482pt;}
# .ws3a{word-spacing:0.007778pt;}
# .ws23{word-spacing:0.012963pt;}
# .ws2f{word-spacing:0.015556pt;}
# .ws22{word-spacing:0.019445pt;}
# .ws32{word-spacing:0.020741pt;}
# .ws1c{word-spacing:0.025463pt;}
# .ws30{word-spacing:0.027831pt;}
# .ws35{word-spacing:0.042779pt;}
# .ws34{word-spacing:0.062224pt;}
# .ws36{word-spacing:0.499086pt;}
# .ws1f{word-spacing:0.553814pt;}
# .ws38{word-spacing:1.298919pt;}
# .ws2e{word-spacing:4.863817pt;}
# .ws26{word-spacing:5.719393pt;}
# .ws2b{word-spacing:5.931990pt;}
# .ws29{word-spacing:6.284591pt;}
# .ws2d{word-spacing:6.403853pt;}
# .ws2c{word-spacing:6.709786pt;}
# .ws27{word-spacing:10.915069pt;}
# .wsf{word-spacing:90.509518pt;}
# ._b{margin-left:-1977.120927pt;}
# ._5{margin-left:-645.304865pt;}
# ._6{margin-left:-551.774906pt;}
# ._0{margin-left:-431.987853pt;}
# ._1{margin-left:-426.543282pt;}
# ._7{margin-left:-417.086580pt;}
# ._2{margin-left:-397.362971pt;}
# ._8{margin-left:-371.728114pt;}
# ._9{margin-left:-350.734106pt;}
# ._a{margin-left:-131.343804pt;}
# ._3{margin-left:-5.200862pt;}
# ._c{width:5.024562pt;}
# ._4{width:689.313855pt;}
# .fs1a{font-size:38.889796pt;}
# .fsd{font-size:51.853022pt;}
# .fsc{font-size:51.853061pt;}
# .fs0{font-size:63.656762pt;}
# .fs9{font-size:63.656797pt;}
# .fs7{font-size:63.656854pt;}
# .fs2{font-size:63.657068pt;}
# .fs4{font-size:63.657152pt;}
# .fs5{font-size:63.657154pt;}
# .fs3{font-size:63.657197pt;}
# .fs6{font-size:63.657213pt;}
# .fsa{font-size:63.657252pt;}
# .fs8{font-size:63.657305pt;}
# .fsb{font-size:64.816327pt;}
# .fs1{font-size:76.387985pt;}
# .fse{font-size:77.779592pt;}
# .fs10{font-size:90.742857pt;}
# .fs12{font-size:92.768367pt;}
# .fs19{font-size:93.983673pt;}
# .fs15{font-size:103.706122pt;}
# .fs13{font-size:116.669388pt;}
# .fsf{font-size:129.632653pt;}
# .fs17{font-size:142.595918pt;}
# .fs11{font-size:194.448980pt;}
# .fs14{font-size:233.338776pt;}
# .fs16{font-size:259.265306pt;}
# .fs18{font-size:453.714286pt;}
# .y0{bottom:7.333333pt;}
# .yd1{bottom:13.845333pt;}
# .yd0{bottom:23.445333pt;}
# .ycf{bottom:33.046133pt;}
# .y35{bottom:40.800095pt;}
# .yce{bottom:42.646133pt;}
# .ycd{bottom:52.246933pt;}
# .ycc{bottom:61.845333pt;}
# .ycb{bottom:71.445333pt;}
# .y34{bottom:77.370667pt;}
# .yca{bottom:81.045333pt;}
# .yc9{bottom:90.645333pt;}
# .y4f{bottom:97.052000pt;}
# .y68{bottom:99.625250pt;}
# .y16{bottom:103.529837pt;}
# .y19{bottom:105.717978pt;}
# .y18{bottom:114.507208pt;}
# .y67{bottom:115.123889pt;}
# .ya{bottom:118.831111pt;}
# .y4e{bottom:121.022667pt;}
# .y1{bottom:124.557467pt;}
# .y17{bottom:126.292528pt;}
# .y2c{bottom:126.613333pt;}
# .y9{bottom:128.322222pt;}
# .y11{bottom:130.197397pt;}
# .y7{bottom:130.223587pt;}
# .yb2{bottom:143.804000pt;}
# .y4d{bottom:144.993333pt;}
# .y36{bottom:160.954667pt;}
# .yb1{bottom:162.470667pt;}
# .y37{bottom:168.206667pt;}
# .y38{bottom:175.037333pt;}
# .y4c{bottom:176.298667pt;}
# .y66{bottom:181.041107pt;}
# .y39{bottom:181.060000pt;}
# .y3a{bottom:184.550667pt;}
# .y3b{bottom:188.176000pt;}
# .y3c{bottom:190.986667pt;}
# .y40{bottom:192.337111pt;}
# .y3d{bottom:192.929333pt;}
# .y3e{bottom:193.360000pt;}
# .y4b{bottom:200.936000pt;}
# .y65{bottom:201.643770pt;}
# .y3f{bottom:202.060000pt;}
# .y1d{bottom:206.463052pt;}
# .y2a{bottom:216.865561pt;}
# .y4a{bottom:225.573333pt;}
# .y3{bottom:226.180972pt;}
# .y24{bottom:227.268070pt;}
# .y2d{bottom:234.125333pt;}
# .y15{bottom:236.667287pt;}
# .y28{bottom:237.670579pt;}
# .y10{bottom:239.184108pt;}
# .y33{bottom:242.928967pt;}
# .yf{bottom:247.157532pt;}
# .y2f{bottom:247.954752pt;}
# .y21{bottom:248.077017pt;}
# .y32{bottom:254.714287pt;}
# .y49{bottom:256.877333pt;}
# .yb4{bottom:256.906667pt;}
# .y27{bottom:257.027313pt;}
# .yc{bottom:257.646466pt;}
# .y1e{bottom:258.480835pt;}
# .y2{bottom:260.740768pt;}
# .y64{bottom:263.851061pt;}
# .y31{bottom:266.229854pt;}
# .y8{bottom:267.990049pt;}
# .y25{bottom:268.880726pt;}
# .y2e{bottom:270.147819pt;}
# .y1b{bottom:272.658345pt;}
# .y74{bottom:273.220000pt;}
# .y63{bottom:277.301333pt;}
# .y30{bottom:277.746731pt;}
# .y26{bottom:279.281925pt;}
# .yd{bottom:279.564543pt;}
# .y48{bottom:280.848000pt;}
# .yb3{bottom:280.906667pt;}
# .y1a{bottom:284.443665pt;}
# .y73{bottom:286.020000pt;}
# .yc0{bottom:286.806667pt;}
# .y2b{bottom:289.261333pt;}
# .y1f{bottom:289.690982pt;}
# .y13{bottom:295.790309pt;}
# .y72{bottom:298.820000pt;}
# .y22{bottom:300.090872pt;}
# .y6{bottom:300.211114pt;}
# .y47{bottom:304.818667pt;}
# .y12{bottom:305.172734pt;}
# .y5{bottom:310.449938pt;}
# .y1c{bottom:310.496000pt;}
# .y71{bottom:311.620000pt;}
# .yc1{bottom:312.401333pt;}
# .ye{bottom:314.557777pt;}
# .y4{bottom:320.688762pt;}
# .y20{bottom:320.898509pt;}
# .y70{bottom:324.418933pt;}
# .y14{bottom:331.268051pt;}
# .y23{bottom:331.299709pt;}
# .y61{bottom:333.948800pt;}
# .y46{bottom:337.456000pt;}
# .yb{bottom:340.561431pt;}
# .y29{bottom:341.700908pt;}
# .y60{bottom:345.682133pt;}
# .y57{bottom:346.750933pt;}
# .y6f{bottom:350.020000pt;}
# .y5f{bottom:357.416533pt;}
# .y56{bottom:358.484267pt;}
# .y45{bottom:361.761333pt;}
# .y6e{bottom:362.820000pt;}
# .y5e{bottom:369.149867pt;}
# .y55{bottom:370.217600pt;}
# .y78{bottom:374.420000pt;}
# .y81{bottom:374.953333pt;}
# .y6d{bottom:375.620000pt;}
# .y5d{bottom:380.883200pt;}
# .y54{bottom:381.950933pt;}
# .y44{bottom:386.065333pt;}
# .y6c{bottom:388.418933pt;}
# .y5c{bottom:392.616533pt;}
# .y53{bottom:393.684267pt;}
# .ybe{bottom:395.225333pt;}
# .y6b{bottom:401.220000pt;}
# .y5b{bottom:404.349867pt;}
# ...
#                             </div>
#                                         <div class="rg-wayPoint" data-track-url="https://www.researchgate.net/publication/track/consume-asset?pid=295548023&lid=56cb315408aee3cee54160e9&fp=ff33a7c5b5dd6b5709ebdfc366f04c40390114fc" data-track-onload="true"></div>
#             </div>
# </div></div></div></div></div></div></section><div id="lite-ad-j7cyopfcpm" class="lite-page-ad lite-page-ad--vertical-spacing-xl lite-page-ad--empty"><div class="lite-page-ad__inner"><div class="lite-page-ad__close"><button class="nova-c-button nova-c-button--align-center nova-c-button--radius-full nova-c-button--size-xs nova-c-button--color-grey nova-c-button--theme-solid nova-c-button--width-square" type="button" id="lite-ad-j7cyopfcpm-close"><svg aria-hidden="true" class="nova-e-icon nova-e-icon--size-s nova-e-icon--theme-bare nova-e-icon--color-inherit nova-e-icon--luminosity-medium nova-c-button__icon"><use xlink:href="/m/454327524547536/images/icons/nova/icon-stack-s.svg#close-s"></use></svg></button></div><script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">document.querySelector('#lite-ad-j7cyopfcpm-close').onclick = function(e) {document.querySelector('#lite-ad-j7cyopfcpm').style.display = 'none';};</script><div id="j7cyopfcpm"><rg-ad id="n5de833j9w" ad-unit="Instream_Video_Mobile" ad-unit-path="/83500759/Instream_Video_Mobile" refresh-timeout="0" load-on-init="true" collapse="never" class="rg-ad" ad-unit-sizes="[[1,1]]" targeting-variants="prd,lite-page" targeting-snippet_id="n5de833j9w" targeting-sequence="1"><rg-ad-size size="[1,1]"></rg-ad-size></rg-ad><script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">document.getElementById("n5de833j9w").addEventListener('adUnitEvent', function(event){if(event.detail.type==="slotRenderEnded"){ if(event.detail.gptEvent.isEmpty){document.querySelector('#lite-ad-j7cyopfcpm').classList.remove('lite-page-ad--rendered');var elem=document.querySelector("#lite-ad-j7cyopfcpm");elem && elem.classList.add('lite-page-ad--empty');}else{document.querySelector('#lite-ad-j7cyopfcpm').classList.add('lite-page-ad--rendered');var elem=document.querySelector("#lite-ad-j7cyopfcpm");elem && elem.classList.remove('lite-page-ad--empty');}}})</script></div></div></div><section class="publication-bottom publication-bottom--redesign"><div class="publication-details__section publication-details__section--redesign"><div class="nova-c-card nova-c-card--spacing-xl nova-c-card--elevation-1-above js-target-citationReferences lite-tabs"><div style="position:relative;width:100%;height:100%" class="publication-citations__menubar"><nav class="nova-c-nav nova-c-nav--direction-horizontal nova-c-nav--theme-tabs nova-c-nav--spread-auto"><div class="nova-c-nav__wrapper"><div class="nova-c-nav__items" role="tablist"><button class="nova-c-nav__item is-selected citations js-lite-click" aria-disabled="false" aria-selected="true" role="tab" type="menu" data-lite="{&quot;click&quot;:[{&quot;t&quot;:&quot;.js-target-citationReferences .lite-page-visible&quot;,&quot;a&quot;:&quot;rc(lite-page-visible)&quot;},{&quot;t&quot;:&quot;.js-target-citationReferences .is-selected&quot;,&quot;a&quot;:&quot;rc(is-selected)&quot;},{&quot;t&quot;:&quot;.js-target-citations&quot;,&quot;a&quot;:&quot;ac(lite-page-visible)&quot;},{&quot;t&quot;:&quot;self&quot;,&quot;a&quot;:&quot;ac(is-selected)&quot;}]}" tabindex="-1"><div><div class="nova-e-text nova-e-text--size-m nova-e-text--family-sans-serif nova-e-text--spacing-none nova-e-text--color-inherit nova-c-nav__item-label"><h2 class="nova-e-text nova-e-text--size-m nova-e-text--family-sans-serif nova-e-text--spacing-none nova-e-text--color-inherit">Citations (0)</h2></div></div></button><button class="nova-c-nav__item references js-lite-click" aria-disabled="false" role="tab" type="menu" data-lite="{&quot;click&quot;:[{&quot;t&quot;:&quot;.js-target-citationReferences .lite-page-visible&quot;,&quot;a&quot;:&quot;rc(lite-page-visible)&quot;},{&quot;t&quot;:&quot;.js-target-citationReferences .is-selected&quot;,&quot;a&quot;:&quot;rc(is-selected)&quot;},{&quot;t&quot;:&quot;.js-target-references&quot;,&quot;a&quot;:&quot;ac(lite-page-visible)&quot;},{&quot;t&quot;:&quot;self&quot;,&quot;a&quot;:&quot;ac(is-selected)&quot;}]}"><div><div class="nova-e-text nova-e-text--size-m nova-e-text--family-sans-s ...
# Рассмотрена методика расчёта рейтинга научной активности преподавателей вуза. Выявлены возможные источники данных и трудности при автоматизации. Сделан вывод о потребности автоматизации цепочки процессов с применением данных не только для расчёта рейтинга, но и для различных отчётов, создания базы по учёным университета с автоматизацией сбора информации для подготовки заявок на конкурсы. Рассмотрены особенности автоматизации учёта потока публикаций университета</span></div><a class="nova-e-link nova-e-link--color-blue nova-e-link--theme-silent publication-recommendation-item__more publication-recommendation-item__more--redesign" href="publication/316107115_Avtomatizacia_rasceta_rejtinga_naucnoj_aktivnosti">View full-text</a></div></div></div></div><div class="nova-o-grid__column nova-o-grid__column--width-6/12@m-up publication-recommendation-item__item"><div class="nova-c-card nova-c-card--spacing-m nova-c-card--elevation-none"><div class="nova-c-card__body nova-c-card__body--spacing-inherit"><div class="publication-recommendation-item publication-recommendation-item--redesign"><div class="nova-l-flex__item nova-l-flex nova-l-flex--gutter-xxs nova-l-flex--direction-row@s-up nova-l-flex--align-items-center@s-up nova-l-flex--justify-content-flex-start@s-up nova-l-flex--wrap-wrap@s-up publication-recommendation-item__item-badges"><div class="nova-l-flex__item"><span class="nova-e-badge nova-e-badge--color-green nova-e-badge--display-inline nova-e-badge--luminosity-high nova-e-badge--size-m nova-e-badge--theme-solid nova-e-badge--radius-m">Article</span></div></div><h3 class="nova-e-text nova-e-text--size-l nova-e-text--family-sans-serif nova-e-text--spacing-xs nova-e-text--color-inherit publication-recommendation-item__title"><a class="nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare gtm-recommendation-item-link" href="publication/2887528_Lexical_Ambiguity_and_Information_Retrieval">Lexical Ambiguity and Information Retrieval</a></h3><div class="nova-e-text nova-e-text--size-s nova-e-text--family-sans-serif nova-e-text--spacing-xs nova-e-text--color-grey-500"><span>August 2002</span> · <span>ACM Transactions on Information Systems</span></div><ul class="nova-e-list nova-e-list--size-m nova-e-list--type-inline nova-e-list--spacing-auto"><li class="nova-e-list__item"><span class="nova-v-person-inline-item"><span class="lite-person-inline-item__image"><picture class="lite-page-avatar lite-page-avatar--size-xs lite-page-avatar--radius-full"> <img src="..." data-src="https://c5.rgstatic.net/m/4671872220764/images/template/default/profile/profile_default_m.jpg" class="lite-image" alt="Robert Krovetz"/></picture></span><span class="nova-v-person-inline-item__fullname"><a class="nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare" href="https://www.researchgate.net/profile/Robert-Krovetz">Robert Krovetz</a></span></span></li><li class="nova-e-list__item"><span class="nova-v-person-inline-item"><span class="nova-v-person-inline-item__fullname"><a class="nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare" href="https://www.researchgate.net/scientific-contributions/W-Bruce-Croft-7937489">W. Bruce Croft</a></span></span></li></ul><div class="nova-e-text nova-e-text--size-s nova-e-text--family-sans-serif nova-e-text--spacing-s nova-e-text--color-grey-500 publication-recommendation-item__abstract">Lexical ambiguity is a pervasive problem in natural language processing. However, little quantitative information is available about the extent of the problem, or about the impact that it has on information retrieval systems. We report on an analysis of lexical ambiguity in information retrieval test collections, and on experiments to determine the utility of word meanings for separating relevant <a class="nova-e-link nova-e-link--color-blue nova-e-link--theme-silent js-lite-click" data-lite="{&quot;click&quot;:[{&quot;t&quot;:&quot;.js-target-5fd5bd81deae9&quot;,&quot;a&quot;:&quot;tc(lite-page-hidden)&quot;},{&q ...
#         (!window.canAskForCookieConsent || !window.canAskForCookieConsent()) && window.loadDeferredObjects && window.loadDeferredObjects();
# </script>
# <script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">if (window.requestConfig) { requestConfig.backendTime = 458; }</script>
# <script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS" async src="https://www.researchgate.net/activeTriggers.js"></script>
# <script src="https://c5.rgstatic.net/m/42673493869132589/javascript/lite/lite.js" crossorigin="anonymous" defer></script>
# <script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">(function () {
# if (document.cookie.indexOf('ga_opt_out') !== -1) {
#     window['ga-disable-UA-58591210-1'] = true;
# }
# })();</script><script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){ (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o), m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m) })(window,document,"script","https://www.google-analytics.com/analytics.js","ga");
# ga("create","UA-58591210-1"); ga("set","anonymizeIp",true); ga("set", "dimension1", "publication full-text");ga("set", "dimension2", "Technical Report");ga("set", "dimension3", "Logged out");ga("set", "dimension4", "lite-page");ga("set", "dimension6", "n\/a");ga("set", "dimension7", "n\/a");ga("set", "dimension8", "n\/a");ga("set", "dimension9", "n\/a");ga("set", "dimension10", "Economics");ga("set", "dimension11", "Data_Mining");ga("set", "dimension12", "Economics Linguistics Political_Science");ga("set", "dimension13", "Data_Mining Artificial_Intelligence Information_Systems_Business_Informatics");(typeof requestCachedConfig!==typeof undefined&&requestCachedConfig.isCachedPage===true)?ga("set", "dimension19", "cache"):ga("set", "dimension19", "no cache"); ; ga("send","pageview");</script>
# <script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">
# document.addEventListener('DOMContentLoaded', function() {
# if (typeof RGCommons === 'undefined') {
#     window.rgCriticalScriptFailure = true;
#     var e = new Error('Critical scripts were not loaded');
#     e.name = 'CriticalScriptsError';
#     throw e;
# } else {
#     RGCommons.parameterFilter.filter(["ev","cp","ch","ref","dbw","pli","loginT","uid","claimChannel","enrichId","enrichSource","utm_source","utm_medium","utm_campaign","utm_term","utm_content","el","ci","mfl"]);
# }
# });
# </script><script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">
# window.addEventListener('load', function() {
# if(typeof RGCommons!=="undefined"){if(RGCommons.rgConfig.getTrackingConfigValue('isCrawler')===false){(typeof requestCachedConfig!==typeof undefined&&requestCachedConfig.isCachedPage===true)?RGCommons.performance.monitorPage("https:\/\/glassmoni.researchgate.net", ["lite.PublicationDetails.run.html.loggedOut.get","lite.PublicationDetails.run.html.loggedOut.get.full-text","lite.PublicationDetails.run.html.loggedOut.get.subcategory-cached","lite.PublicationDetails.run.html.loggedOut.get.subcategory-full-text-cached"], "5ded741496c77f49c3adf33a496b0a8164ae6652"):RGCommons.performance.monitorPage("https:\/\/glassmoni.researchgate.net", ["lite.PublicationDetails.run.html.loggedOut.get","lite.PublicationDetails.run.html.loggedOut.get.full-text","lite.PublicationDetails.run.html.loggedOut.get.subcategory-non-cached","lite.PublicationDetails.run.html.loggedOut.get.subcategory-full-text-non-cached"], "e76dd17902432470f4004f64a2ac602fd200b44d");}if(RGCommons.rgConfig.getTrackingConfigValue('isCrawler')===true){RGCommons.performance.monitorPage("https:\/\/glassmoni.researchgate.net", ["lite.PublicationDetails.run.html.loggedOut.get","lite.PublicationDetails.run.html.loggedOut.get.full-text","lite.PublicationDetails.run.html.loggedOut.get.subcategory-crawler"], "1102f002b4b24bd0bdd29c3d4cec66424ed32c4a");}}
# });
# </script>
# <script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS"> dataLayer = [{"pageCategory":"publication full-text","publicationType":"Technical Report","eventCategory":"Publication page"}] </script><noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MKVKH7" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-MKVKH7');</script>
# <script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">
# var googletag=googletag||{};googletag.cmd=googletag.cmd||[];
# (function(){var gads=document.createElement("script");gads.async=true;gads.type="text/javascript";gads.src="https://securepubads.g.doubleclick.net/tag/js/gpt.js";var node=document.getElementsByTagName("script")[0];node.parentNode.insertBefore(gads,node);})();
# </script>
# <script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">!function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");</script><script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">var rgDelivery=rgDelivery||{};rgDelivery.cmd=rgDelivery.cmd||[];var deliveryManager=deliveryManager||{_q:[]};deliveryManager.start=deliveryManager.start||function(){deliveryManager._q.push(['s', arguments]);};(function(){var tag=document.createElement("script");tag.async=true;tag.type="text/javascript";tag.src="https://www.researchgate.net/delivery/manager.js?rgKey=PB%3A295548023&qc=1";var node=document.getElementsByTagName("script")[0];node.parentNode.insertBefore(tag,node);})();</script>
# <script nonce="BfaIsQsMt0LRQGjDBzEfnj0IXblsxoXS">
# document.addEventListener('DOMContentLoaded', function() {
# deliveryManager.start();
# });
# </script></body></html>

# %%
url = "https://doi.org/10.1126/science.169.3946.635" #DOI solver URL
headers = {'Accept': 'application/rdf+xml'} #Type of response accepted
r = requests.get(url, headers=headers) #GET with headers
print(r.status_code)
print(r.text)
# Out:
# 200
# <rdf:RDF
#     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#     xmlns:j.0="http://purl.org/dc/terms/"
#     xmlns:j.1="http://prismstandard.org/namespaces/basic/2.1/"
#     xmlns:owl="http://www.w3.org/2002/07/owl#"
#     xmlns:j.2="http://purl.org/ontology/bibo/"
#     xmlns:j.3="http://xmlns.com/foaf/0.1/">
#   <rdf:Description rdf:about="http://dx.doi.org/10.1126/science.169.3946.635">
#     <j.1:startingPage>635</j.1:startingPage>
#     <owl:sameAs rdf:resource="doi:10.1126/science.169.3946.635"/>
#     <owl:sameAs rdf:resource="info:doi/10.1126/science.169.3946.635"/>
#     <j.0:identifier>10.1126/science.169.3946.635</j.0:identifier>
#     <j.0:publisher>American Association for the Advancement of Science (AAAS)</j.0:publisher>
#     <j.0:creator>
#       <j.3:Person rdf:about="http://id.crossref.org/contributor/h-s-frank-3new7r2ulpnaj">
#         <j.3:name>H. S. Frank</j.3:name>
#         <j.3:familyName>Frank</j.3:familyName>
#         <j.3:givenName>H. S.</j.3:givenName>
#       </j.3:Person>
#     </j.0:creator>
#     <j.1:doi>10.1126/science.169.3946.635</j.1:doi>
#     <j.2:pageEnd>641</j.2:pageEnd>
#     <j.2:doi>10.1126/science.169.3946.635</j.2:doi>
#     <j.2:volume>169</j.2:volume>
#     <j.0:isPartOf>
#       <j.2:Journal rdf:about="http://id.crossref.org/issn/0036-8075">
#         <j.1:issn>1095-9203</j.1:issn>
#         <j.2:issn>1095-9203</j.2:issn>
#         <owl:sameAs>urn:issn:1095-9203</owl:sameAs>
#         <owl:sameAs>urn:issn:0036-8075</owl:sameAs>
#         <j.0:title>Science</j.0:title>
#         <j.1:issn>0036-8075</j.1:issn>
#         <j.2:issn>0036-8075</j.2:issn>
#       </j.2:Journal>
#     </j.0:isPartOf>
#     <j.0:title>The Structure of Ordinary Water: New data and interpretations are yielding new insights into this fascinating substance</j.0:title>
#     <j.1:endingPage>641</j.1:endingPage>
#     <j.0:date rdf:datatype="http://www.w3.org/2001/XMLSchema#date"
#     >1970-08-14</j.0:date>
#     <j.1:volume>169</j.1:volume>
#     <j.2:pageStart>635</j.2:pageStart>
#   </rdf:Description>
# </rdf:RDF>

# %% [markdown]
# ## JSON - JavaScript Object Notation
# When exchanging data between a browser and a server, the data can only be text.
#
# JSON is text, and we can convert any JavaScript object into JSON, and send JSON to the server.
#
# Similar to XML
#
# We can also convert any JSON received from the server into JavaScript objects.
#
# This way we can work with the data as JavaScript objects, with no complicated parsing and translations.
#
# Different python libraries are oriented to manage JSON objects or files, and the information can be parsed easily. From the previous request, we can get the answer in JSON format and store it in a variable:

# %%
url = "https://doi.org/10.1126/science.169.3946.635" #DOI solver URL
headers = {'Accept': 'application/json'} #Type of response accepted
r = requests.get(url, headers=headers) #GET with headers
print("Status code: %s" % r.status_code) #200 means that the resource exists
print("Response: %s" % r.text)
# Out:
# Status code: 200
# Response: {"indexed":{"date-parts":[[2020,9,4]],"date-time":"2020-09-04T09:05:42Z","timestamp":1599210342016},"reference-count":0,"publisher":"American Association for the Advancement of Science (AAAS)","issue":"3946","content-domain":{"domain":[],"crossmark-restriction":false},"published-print":{"date-parts":[[1970,8,14]]},"DOI":"10.1126\/science.169.3946.635","type":"article-journal","created":{"date-parts":[[2006,10,5]],"date-time":"2006-10-05T12:56:56Z","timestamp":1160053016000},"page":"635-641","source":"Crossref","is-referenced-by-count":74,"title":"The Structure of Ordinary Water: New data and interpretations are yielding new insights into this fascinating substance","prefix":"10.1126","volume":"169","author":[{"given":"H. S.","family":"Frank","sequence":"first","affiliation":[]}],"member":"221","container-title":"Science","original-title":[],"language":"en","link":[{"URL":"https:\/\/syndication.highwire.org\/content\/doi\/10.1126\/science.169.3946.635","content-type":"unspecified","content-version":"vor","intended-application":"similarity-checking"}],"deposited":{"date-parts":[[2020,2,5]],"date-time":"2020-02-05T16:15:06Z","timestamp":1580919306000},"score":1.0,"subtitle":[],"short-title":[],"issued":{"date-parts":[[1970,8,14]]},"references-count":0,"journal-issue":{"published-print":{"date-parts":[[1970,8,14]]},"issue":"3946"},"URL":"http:\/\/dx.doi.org\/10.1126\/science.169.3946.635","relation":{},"ISSN":["0036-8075","1095-9203"],"subject":["Multidisciplinary"],"container-title-short":"Science"}

# %% [markdown]
# ### 3.2 Response Codes
#
# Code	Meaning<br>
# 200	The request was OK.<br>
# 204	The request was OK but there was no metadata available.<br>
# 404	The DOI requested doesn't exist.<br>
# 406	Can't serve any requested content type.<br>
#
# Individual metadata services may utilise additional response codes but they will always use the response codes above in event of the case described.
#
# If multiple content types specified by the client are supported by a DOI then the content type with the highest "q" value (or, if no "q" values are specified, the one that appears first in the "accept" header) will be returned.

# %% [markdown]
# After ask for a json response, if we get a 200, we can transform that received text into JSON

# %%
data = json.loads(r.text) #Data is now a json object
print(data)
# Out:
# {'indexed': {'date-parts': [[2020, 9, 4]], 'date-time': '2020-09-04T09:05:42Z', 'timestamp': 1599210342016}, 'reference-count': 0, 'publisher': 'American Association for the Advancement of Science (AAAS)', 'issue': '3946', 'content-domain': {'domain': [], 'crossmark-restriction': False}, 'published-print': {'date-parts': [[1970, 8, 14]]}, 'DOI': '10.1126/science.169.3946.635', 'type': 'article-journal', 'created': {'date-parts': [[2006, 10, 5]], 'date-time': '2006-10-05T12:56:56Z', 'timestamp': 1160053016000}, 'page': '635-641', 'source': 'Crossref', 'is-referenced-by-count': 74, 'title': 'The Structure of Ordinary Water: New data and interpretations are yielding new insights into this fascinating substance', 'prefix': '10.1126', 'volume': '169', 'author': [{'given': 'H. S.', 'family': 'Frank', 'sequence': 'first', 'affiliation': []}], 'member': '221', 'container-title': 'Science', 'original-title': [], 'language': 'en', 'link': [{'URL': 'https://syndication.highwire.org/content/doi/10.1126/science.169.3946.635', 'content-type': 'unspecified', 'content-version': 'vor', 'intended-application': 'similarity-checking'}], 'deposited': {'date-parts': [[2020, 2, 5]], 'date-time': '2020-02-05T16:15:06Z', 'timestamp': 1580919306000}, 'score': 1.0, 'subtitle': [], 'short-title': [], 'issued': {'date-parts': [[1970, 8, 14]]}, 'references-count': 0, 'journal-issue': {'published-print': {'date-parts': [[1970, 8, 14]]}, 'issue': '3946'}, 'URL': 'http://dx.doi.org/10.1126/science.169.3946.635', 'relation': {}, 'ISSN': ['0036-8075', '1095-9203'], 'subject': ['Multidisciplinary'], 'container-title-short': 'Science'}

# %% [markdown]
# In order to know the different elements in the JSON, we can run a loop:
# <div class="alert alert-warning" role="alert" style="margin: 10px">
# Remember "tags" in XML?
# </div>

# %%
for elem in data:
    print(elem)
# Out:
# indexed
# reference-count
# publisher
# issue
# content-domain
# published-print
# DOI
# type
# created
# page
# source
# is-referenced-by-count
# title
# prefix
# volume
# author
# member
# container-title
# original-title
# language
# link
# deposited
# score
# subtitle
# short-title
# issued
# references-count
# journal-issue
# URL
# relation
# ISSN
# subject
# container-title-short

# %% [markdown]
# For getting the value, it works like "dictionary" in python (Key-Value)

# %%
data['URL']
# Out:
# 'http://dx.doi.org/10.1126/science.169.3946.635'

# %% [markdown]
# You can also print both keys and values to know the JSON structure

# %%
for elem in data:
    print(elem,":", data[elem])
# Out:
# indexed : {'date-parts': [[2020, 9, 4]], 'date-time': '2020-09-04T09:05:42Z', 'timestamp': 1599210342016}
# reference-count : 0
# publisher : American Association for the Advancement of Science (AAAS)
# issue : 3946
# content-domain : {'domain': [], 'crossmark-restriction': False}
# published-print : {'date-parts': [[1970, 8, 14]]}
# DOI : 10.1126/science.169.3946.635
# type : article-journal
# created : {'date-parts': [[2006, 10, 5]], 'date-time': '2006-10-05T12:56:56Z', 'timestamp': 1160053016000}
# page : 635-641
# source : Crossref
# is-referenced-by-count : 74
# title : The Structure of Ordinary Water: New data and interpretations are yielding new insights into this fascinating substance
# prefix : 10.1126
# volume : 169
# author : [{'given': 'H. S.', 'family': 'Frank', 'sequence': 'first', 'affiliation': []}]
# member : 221
# container-title : Science
# original-title : []
# language : en
# link : [{'URL': 'https://syndication.highwire.org/content/doi/10.1126/science.169.3946.635', 'content-type': 'unspecified', 'content-version': 'vor', 'intended-application': 'similarity-checking'}]
# deposited : {'date-parts': [[2020, 2, 5]], 'date-time': '2020-02-05T16:15:06Z', 'timestamp': 1580919306000}
# score : 1.0
# subtitle : []
# short-title : []
# issued : {'date-parts': [[1970, 8, 14]]}
# references-count : 0
# journal-issue : {'published-print': {'date-parts': [[1970, 8, 14]]}, 'issue': '3946'}
# URL : http://dx.doi.org/10.1126/science.169.3946.635
# relation : {}
# ISSN : ['0036-8075', '1095-9203']
# subject : ['Multidisciplinary']
# container-title-short : Science

# %% [markdown]
# ## 4 Formatted Citations
#
# CrossRef, DataCite and similar services support formatted citations via the text/bibliography content type. These are the output of the Citation Style Language processor, citeproc-js. The content type can take two additional parameters to customise its response format. A "style" can be chosen from the list of style names found in the CSL style repository. Many styles are supported, including common styles such as apa and harvard3:

# %%
url = "https://doi.org/10.1126/science.169.3946.635" #DOI solver URL
headers = {'Accept': 'text/x-bibliography; style=bibtex'} #Type of response accepted
r = requests.get(url, headers=headers) #POST with headers
print(r.status_code)
print(r.text)
# Out:
# 200
#  @article{Frank_1970, title={The Structure of Ordinary Water: New data and interpretations are yielding new insights into this fascinating substance}, volume={169}, ISSN={1095-9203}, url={http://dx.doi.org/10.1126/science.169.3946.635}, DOI={10.1126/science.169.3946.635}, number={3946}, journal={Science}, publisher={American Association for the Advancement of Science (AAAS)}, author={Frank, H. S.}, year={1970}, month={Aug}, pages={635â641}}

# %% [markdown]
# ### Let's try with a DOI at Zenodo

# %%
url = "https://doi.org/10.5281/zenodo.842715" #DOI solver URL
headers = {'Accept': 'application/vnd.citationstyles.csl+json;q=1.0'} #Type of response accepted
r = requests.post(url, headers=headers) #POST with headers
print(r.status_code)
print(r.text)
# Out:
# 200
# {
#   "type": "dataset",
#   "id": "https://doi.org/10.5281/zenodo.842715",
#   "categories": [
#     "Cuerda del Pozo",
#     "Reservoir",
#     "Freshwater",
#     "Water Quality",
#     "AMT",
#     "beginDate:'2010-01-01'",
#     "endDate:'2010-12-31'",
#     "location:'CdP'",
#     "attributeLabel:'Temp'",
#     "attributeLabel:'Press'",
#     "attributeLabel:'Cond'",
#     "attributeLabel:'Salinity'",
#     "attributeLabel:'DO'",
#     "attributeLabel:'rawO2'",
#     "attributeLabel:'OxySat'",
#     "attributeLabel:'ph'",
#     "attributeLabel:'redox'",
#     "gnd:2010-01-01"
#   ],
#   "author": [
#     {
#       "family": "Aguilar",
#       "given": "Fernando"
#     },
#     {
#       "family": "Marco",
#       "given": "Jesús"
#     },
#     {
#       "family": "Monteoliva",
#       "given": "Agustín"
#     }
#   ],
#   "issued": {
#     "date-parts": [
#       [
#         2017,
#         8,
#         14
#       ]
#     ]
#   },
#   "abstract": "AMT data from Cuerda del Pozo Reservoir in 2010. It includes: Temperature, Pressure, Conductivity, Dissolved Oxygen, raw O2, Oxygen saturation, ph and redex values.",
#   "DOI": "10.5281/ZENODO.842715",
#   "publisher": "Zenodo",
#   "title": "Amt Cuerda Del Pozo 2010",
#   "URL": "https://zenodo.org/record/842715",
#   "copyright": "Creative Commons Attribution 4.0"
# }

# %% [markdown]
# ## Exercise 1
# Show title and description

# %%
zenodo_json = json.loads(r.text)
print("Title:",zenodo_json['title'], "\nDescription:",zenodo_json['abstract'])
# Out:
# Title: Amt Cuerda Del Pozo 2010
# Description: AMT data from Cuerda del Pozo Reservoir in 2010. It includes: Temperature, Pressure, Conductivity, Dissolved Oxygen, raw O2, Oxygen saturation, ph and redex values.

# %% [markdown]
# # Solving PIDs
# With Handle

# %% [markdown]
# By default, handle redirects you to the URL field in PID

# %%
import requests

url = "http://hdl.handle.net/1895.22/1013" #PID solver URL
r = requests.get(url) #GET
print(r.status_code)
print(r.text)
# Out:
# 200
# <HTML>
# <HEAD>
# <META HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=windows-1252">
# <META NAME="Generator" CONTENT="Microsoft Word 97">
# <TITLE>License for PYTHON 1.6.1</TITLE>
# </HEAD>
# <BODY LINK="#0000ff" VLINK="#800080">
#
# <FONT FACE="Century Schoolbook">
# <P>&nbsp;</P>
# <P ALIGN="CENTER">PYTHON 1.6.1</P>
# <P ALIGN="CENTER">PYTHON 1.6.1 LICENSE AGREEMENT<BR>
# </P>
# <P>1. This LICENSE AGREEMENT is between the Corporation for National Research Initiatives, having an office at 1895 Preston White Drive, Reston, VA 20191 ("CNRI"), and the Individual or Organization ("Licensee") accessing and otherwise using Python 1.6.1 software in source or binary form and its associated documentation.</P>
#
# <P>2. Subject to the terms and conditions of this License Agreement, CNRI hereby grants Licensee a nonexclusive, royalty-free, world-wide license to reproduce, analyze, test, perform and/or display publicly, prepare derivative works, distribute, and otherwise use Python 1.6.1 alone or in any derivative version, provided, however, that CNRI's License Agreement and CNRI's notice of copyright, i.e., "Copyright(c) 1995-2001 Corporation for National Research Initiatives; All Rights Reserved" are retained in Python 1.6.1 alone or in any derivative version prepared by Licensee. Alternately, in lieu of CNRI's License Agreement, Licensee may substitute the following text (omitting the quotes): "Python 1.6.1 is made available subject to the terms and conditions in CNRI's License Agreement. This Agreement together with Python 1.6.1 may be located on the Internet using the following unique, persistent identifier (known as a handle): 1895.22/1013. This Agreement may also be obtained from a proxy server on the Internet using the following URL: </FONT><A HREF="http://hdl.handle.net/1895.22/1013"><FONT FACE="Century Schoolbook">http://hdl.handle.net/1895.22/1013</FONT></A><FONT FACE="Century Schoolbook">".</P>
#
# <P>3. In the event Licensee prepares a derivative work that is based on or incorporates Python 1.6.1 or any part thereof, and wants to make the derivative work available to others as provided herein, then Licensee hereby agrees to include in any such work a brief summary of the changes made to Python 1.6.1.</P>
#
# <P>4. CNRI is making Python 1.6.1 available to Licensee on an "AS IS" basis. CNRI MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR IMPLIED. BY WAY OF EXAMPLE, BUT NOT LIMITATION, CNRI MAKES NO AND DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF PYTHON 1.6.1 WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.</P>
#
# <P>5. CNRI SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF PYTHON 1.6.1 FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING PYTHON 1.6.1, OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF THE POSSIBILITY THEREOF.</P>
#
# <P>6. This License Agreement will automatically terminate upon a material breach of its terms and conditions.</P>
#
# <P>7. This License Agreement shall be governed by the federal intellectual
# property law of the United States, including without limitation the federal
# copyright law, and, to the extent such U.S. federal law does not apply, by
# the law of the Commonwealth of Virginia, excluding Virginia's conflict of law
# provisions.  Notwithstanding the foregoing, with regard to derivative works
# based on Python 1.6.1 that incorporate non-separable material that was
# previously distributed under the GNU General Public License (GPL), the law
# of the Commonwealth of Virginia shall govern this License Agreement only
# as to issues arising under or with respect to Paragraphs 4, 5, and 7 of this
# License Agreement. Nothing in this License Agreement shall be deemed to create any relationship of agency, partnership, or joint venture between CNRI and Licensee. This License Agreement does not grant permission to use CNRI trademarks or trade name in a trademark sense to endorse or promote products or services of Licensee, or any third party.</P>
#
# <P>8. By clicking on the "ACCEPT" button where indicated, or by copying, installing or otherwise using Python 1.6.1, Licensee agrees to be bound by the terms and conditions of this License Agreement.</P>
#
# <P ALIGN="CENTER">ACCEPT</P>
# <P></P></FONT></BODY>
# </HTML>

# %% [markdown]
# The handle System has different options that we can manage:
#
# http://www.handle.net/proxy_servlet.html
#
# For example, we can tell the server not to redirect to URL field:

# %%
import requests
import json

url = "http://hdl.handle.net/1895.22/1013?noredirect" #PID URL with ?noredirect
r = requests.get(url) #GET with headers
print(r.status_code)
print(r.text)
# Out:
# 200
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <html><head><title>Handle Proxy</title></head>
#
# <body bgcolor="#ffffff">
#
# <a href="http://www.handle.net">
# <img src="/static/images/res_tool.gif" width="270" height="40" alt="Handle.net Logo" border=0></a>
#
# <table width="100%">
# <tbody>
# <tr><th colspan="4" align="left" bgcolor="#dddddd">Handle Values for: 1895.22/1013</th></tr>
# <tr><td align="left" valign="top">Index</td><td align="left" valign="top">Type</td><td align="left" valign="top">Timestamp</td><td align="left" valign="top">Data</td></tr>
# <tr bgcolor="#dddddd"><td align="left" valign="top"><b>100</b></td><td align="left" valign="top"><b><a href="http://hdl.handle.net/0.TYPE/HS_ADMIN">HS_ADMIN</a></b></td><td valign="top"><span style='white-space:nowrap'>2015-04-03&nbsp;21:20:10Z</span></td>
# <td>handle=200/1; index=300; [create hdl,delete hdl,create derived prefix,delete derived prefix,read val,modify val,del val,add val,modify admin,del admin,add admin,list]</td></tr>
# <tr bgcolor="#ffffff"><td align="left" valign="top"><b>3</b></td><td align="left" valign="top"><b><a href="http://hdl.handle.net/0.TYPE/URL">URL</a></b></td><td valign="top"><span style='white-space:nowrap'>2015-04-03&nbsp;21:20:10Z</span></td>
# <td><a href="http://www.handle.net/python_licenses/python1.6.1-2-23-01.html">http://www.handle.net/python_licenses/python1.6.1-2-23-01.html</a></td></tr>
#
#
# </tbody></table>
#
#
# <p><strong><em><small>
# <a href="/help.html">Handle Proxy Server Documentation</a><br/>
# <a href="http://www.handle.net/">Handle.net Web Site</a>
# </small>
# </em></strong></p>
# <p><i>Please contact <a href="mailto:hdladmin@cnri.reston.va.us?subject=Handle%20Questions%20and%20Comments">hdladmin@cnri.reston.va.us</a> for your handle questions and comments</i>.
#
# </body></html>

# %% [markdown]
# ### Query Parameters
#
# This proxy server system REST API is CORS-compliant, however, JSONP callbacks are also supported using a "callback" query parameter.
#
# The presence of the "pretty" query parameter instructs the server to pretty-print the JSON output.
#
# The "auth" query parameter instructs the proxy server to bypass its cache and query a primary handle server directly for the newest handle data.
#
# The "cert" query parameter instructs the proxy server to request an authenticated response from the source handle server. Not generally needed by end users.
#
# The "type" and "index" query parameters allow the resolution response to be restricted to specific types and indexes of interest. "Type" is the key defined by the user to store a metadata term. "Index" is a number associated to that term. Multiple "type" and "index" parameters are allowed and values are returned which match any of the specified types or indexes. For example,
#
# For example, http://hdl.handle.net/api/handles/4263537/4000?type=URL&type=EMAIL&callback=processResponse yields the response
#
# ```JSON
# processResponse({
#    "responseCode":1,
#    "handle":"4263537/4000",
#    "values":[
#       {
#          "index":1,
#          "type":"URL",
#          "data":{ "format":"string", "value":"http://www.handle.net/index.html" },
#          "ttl":86400,
#          "timestamp":"2001-11-21T16:21:35Z"
#       },
#       {
#          "index":2,
#          "type":"EMAIL",
#          "data":{ "format":"string", "value":"hdladmin@cnri.reston.va.us" },
#          "ttl":86400,
#          "timestamp":"2000-04-10T22:41:46Z"
#       }
#    ]
# });
# ```

# %% [markdown]
# <div class="alert alert-warning" role="alert" style="margin: 10px">
# Recuerda!<br>
# Si no indicas el Content-type, el servidor actuará como si recibiera una petición por navegador, devolviendo un html
# </div>

# %%
import requests
import json

url = "http://hdl.handle.net/api/handles/4263537/4000?type=URL&type=EMAIL&callback=processResponse" #PID URL with ?noredirect
headers = {'Content-Type': 'application/json'} #Type of response accepted
r = requests.get(url, headers=headers) #POST with headers
print(r.text)
# Out:
# processResponse({"responseCode":1,"handle":"4263537/4000","values":[{"index":1,"type":"URL","data":{"format":"string","value":"http://www.handle.net/index.html"},"ttl":86400,"timestamp":"2015-04-03T21:20:22Z"},{"index":2,"type":"EMAIL","data":{"format":"string","value":"hdladmin@cnri.reston.va.us"},"ttl":86400,"timestamp":"2015-04-03T21:20:22Z"}]});

# %% [markdown]
# # Exercise 2

# %% [markdown]
# * 1: Try to find *TWO* different repositories that manage PIDs or DOIs (e.g journals, figshare.com, DataONE, zenodo, digital.CSIC, etc.)
# * 2: Check an example file or the documentation to get the identifier from a resource
# * 3: Resolve the identifier using python request
# * 4: Show relevant information, like author, title, description...
# * 5: Which kind of "types" are defined in the PIDs?
# * 6: Is there any difference managing the DOIs/PIDs between the different repositories? (textual answer)

# %% [markdown]
# * 1: Try to find *TWO* different repositories that manage PIDs or DOIs (e.g journals, figshare.com, DataONE, zenodo, digital.CSIC, etc.)
#
# **For this excercise we will use both Zenodo: https://zenodo.org/ and Figshare: https://figshare.com/ .**

# %% [markdown]
# * 2: Check an example file or the documentation to get the identifier from a resource
#
# **We will use the following repositories:**
#
# https://zenodo.org/record/4317829#.X9XF8thKiUk
#
# https://figshare.com/collections/Supplementary_material_from_How_do_habitat_amount_and_habitat_fragmentation_drive_time-delayed_responses_of_biodiversity_to_land-use_change_/5238519

# %% [markdown]
# * 3: Resolve the identifier using python request

# %%
#Using Zenodo:
urlzen = "https://doi.org/10.5281/zenodo.4317829" #DOI solver URL
headerszen = {'Accept': 'application/vnd.citationstyles.csl+json;q=1.0'} #Type of response accepted
rzen = requests.post(urlzen, headers=headerszen) #POST with headers
print("Status code = ",rzen.status_code)
# Out:
# Status code =  200

# %%
#Using Figshare:
urlfig = "https://doi.org/10.6084/m9.figshare.c.5238519.v1" #DOI solver URL
headersfig = {'Accept': 'application/vnd.citationstyles.csl+json;q=1.0'} #Type of response accepted
rfig = requests.post(urlfig, headers=headersfig) #POST with headers
print("Status code = ",rfig.status_code)
# Out:
# Status code =  200

# %% [markdown]
# * 4: Show relevant information, like author, title, description...

# %%
#Using Zenodo:
datazen = json.loads(rzen.text) #Data is now a json object
for elem in datazen:
    print("\n",elem,":", datazen[elem])
# Out:
#  type : dataset
#
#  id : https://doi.org/10.5281/zenodo.4317829
#
#  categories : ['COVID-19', 'coronavirus', 'scientometrics', 'bibliometrics']
#
#  author : [{'family': 'Vergoulis', 'given': 'Thanasis'}, {'family': 'Kanellos', 'given': 'Ilias'}, {'family': 'Chatzopoulos', 'given': 'Serafeim'}, {'family': 'Karidi', 'given': 'Danae Pla'}, {'family': 'Dalamagas', 'given': 'Theodore'}]
#
#  issued : {'date-parts': [[2020, 12, 11]]}
#
#  abstract : This dataset contains impact metrics and indicators for a set of publications that are related to the COVID-19 infectious disease and the coronavirus that causes it. It is based on: Τhe CORD-19 dataset released by the team of Semantic Scholar<sup>1</sup> and Τhe curated data provided by the LitCovid hub<sup>2</sup>. These data have been cleaned and integrated with data from COVID-19-TweetIDs and from other sources (e.g., PMC). The result was dataset of 219,652 unique articles along with relevant metadata (e.g., the underlying citation network). We utilized this dataset to produce, for each article, the values of the following impact measures: <em><strong>Influence:</strong></em> Citation-based measure reflecting the total impact of an article. This is based on the PageRank<sup>3</sup> network analysis method. In the context of citation networks, it estimates the importance of each article based on its centrality in the whole network. This measure was calculated using the PaperRanking (https://github.com/diwis/PaperRanking) library<sup>4</sup>. <em><strong>Popularity:</strong></em> Citation-based measure reflecting the current impact of an article. This is based on the AttRank<sup>5</sup> citation network analysis method. Methods like PageRank are biased against recently published articles (new articles need time to receive their first citations). AttRank alleviates this problem incorporating an attention-based mechanism, akin to a time-restricted version of preferential attachment, to explicitly capture a researcher's preference to read papers which received a lot of attention recently. This is why it is more suitable to capture the current "hype" of an article. <em><strong>Popularity alternative:</strong></em> An alternative citation-based measure reflecting the current impact of an article (this was the basic popularity measured provided by BIP4COVID19 until version 26). This is based on the RAM<sup>6</sup> citation network analysis method. Methods like PageRank are biased against recently published articles (new articles need time to receive their first citations). RAM alleviates this problem using an approach known as "time-awareness". This is why it is more suitable to capture the current "hype" of an article. This measure was calculated using the PaperRanking (https://github.com/diwis/PaperRanking) library<sup>4</sup>. <em><strong>Social Media Attention: </strong></em>The number of tweets related to this article. Relevant data were collected from the COVID-19-TweetIDs dataset. In this version, tweets between 1/11-6/11 have been considered from the previous dataset. We provide four CSV files, all containing the same information, however each having its entries ordered by a different impact measure. All CSV files are tab separated and have the same columns (PubMed_id, PMC_id, DOI, influence_score, popularity_alt_score, popularity score, tweets count). The work is based on the following publications: COVID-19 Open Research Dataset (CORD-19). 2020. Version 2020-11-28 Retrieved from https://pages.semanticscholar.org/coronavirus-research. Accessed 2020-11-28. doi:10.5281/zenodo.3715506 Chen Q, Allot A, &amp; Lu Z. (2020) Keep up with the latest coronavirus research, Nature 579:193 (version 2020-11-28) R. Motwani L. Page, S. Brin and T. Winograd. 1999. The PageRank Citation Ranking: Bringing Order to the Web. Technical Report. Stanford InfoLab. I. Kanellos, T. Vergoulis, D. Sacharidis, T. Dalamagas, Y. Vassiliou: Impact-Based Ranking of Scientific Publications: A Survey and Experimental Evaluation. TKDE 2019 I. Kanellos, T. Vergoulis, D. Sacharidis, T. Dalamagas, Y. Vassiliou: Ranking Papers by their Short-Term Scientific Impact. CoRR abs/2006.00951 (2020) Rumi Ghosh, Tsung-Ting Kuo, Chun-Nan Hsu, Shou-De Lin, and Kristina Lerman. 2011. Time-Aware Ranking in Dynamic Citation Networks. In Data Mining Workshops (ICDMW). 373–380 A Web user interface that uses these data to facilitate the COVID-19 literature exploration ...
#
#  DOI : 10.5281/ZENODO.4317829
#
#  publisher : Zenodo
#
#  title : BIP4COVID19: Impact metrics and indicators for coronavirus related publications
#
#  URL : https://zenodo.org/record/4317829
#
#  copyright : Creative Commons Attribution 4.0 International
#
#  version : 27

# %%
#Using Figshare:
datafig = json.loads(rfig.text) #Data is now a json object
for elem in datafig:
    print("\n",elem,":", datafig[elem])
# Out:
#  type : article
#
#  id : https://doi.org/10.6084/m9.figshare.c.5238519.v1
#
#  categories : ['Ecology', 'FOS: Biological sciences', 'FOS: Biological sciences']
#
#  author : [{'family': 'Semper-Pascual', 'given': 'Asunción'}, {'family': 'Burton', 'given': 'Cole'}, {'family': 'Baumann', 'given': 'Matthias'}, {'family': 'Decarre', 'given': 'Julieta'}, {'family': 'Gavier-Pizarro', 'given': 'Gregorio'}, {'family': 'Gómez-Valencia', 'given': 'Bibiana'}, {'family': 'Macchi', 'given': 'Leandro'}, {'family': 'Mastrangelo', 'given': 'Matías E.'}, {'family': 'Pötzschner', 'given': 'Florian'}, {'family': 'Zelaya', 'given': 'Patricia V.'}, {'family': 'Kuemmerle', 'given': 'Tobias'}]
#
#  issued : {'date-parts': [[2020]]}
#
#  abstract : Land-use change is a root cause of the extinction crisis, but links between habitat change and biodiversity loss are not fully understood. While there is evidence that habitat loss is an important extinction driver, the relevance of habitat fragmentation remains debated. Moreover, while time delays of biodiversity responses to habitat transformation are well-documented, time-delayed effects have been ignored in the habitat loss versus fragmentation debate. Here, using a hierarchical Bayesian multi-species occupancy framework, we systematically tested for time-delayed responses of bird and mammal communities to habitat loss and to habitat fragmentation. We focused on the Argentine Chaco, where deforestation has been widespread recently. We used an extensive field dataset on birds and mammals, along with a time series of annual woodland maps from 1985 to 2016 covering recent and historical habitat transformations. Contemporary habitat amount explained bird and mammal occupancy better than past habitat amount. However, occupancy was affected more by the past rather than recent fragmentation, indicating a time-delayed response to fragmentation. Considering past landscape patterns is therefore crucial for understanding current biodiversity patterns. Not accounting for land-use history ignores the possibility of extinction debt and can thus obscure impacts of fragmentation, potentially explaining contrasting findings of habitat loss versus fragmentation studies.
#
#  DOI : 10.6084/M9.FIGSHARE.C.5238519.V1
#
#  publisher : The Royal Society
#
#  title : Supplementary material from "How do habitat amount and habitat fragmentation drive time-delayed responses of biodiversity to land-use change?"
#
#  URL : https://rs.figshare.com/collections/Supplementary_material_from_How_do_habitat_amount_and_habitat_fragmentation_drive_time-delayed_responses_of_biodiversity_to_land-use_change_/5238519/1
#
#  copyright : Creative Commons Attribution 4.0 International

# %% [markdown]
# * 5: Which kind of "types" are defined in the PIDs?

# %%
#Using Zenodo:
print("The type of the PID is:",datazen['type'])
# Out:
# The type of the PID is: dataset

# %%
#Using Figshare:
print("The type of the PID is:",datafig['type'])
# Out:
# The type of the PID is: article

# %% [markdown]
# * 6: Is there any difference managing the DOIs/PIDs between the different repositories? (textual answer)

# %% [markdown]
# For the use that we have given both repositories (Zenodo, Figshare) in the above exercises I did not see any noticeable differences. Both were easy to browse through and find everything that we needed for the exercises.
#
# Doing some research I found that the main differences are in the author's side of things:
#
# Nature.com has a breakdown of the differences between generalist repositories: https://www.nature.com/sdata/policies/repositories#toc
#
# Zenodo has a direct comparison between its service and Figshare's: https://doi.org/10.5281/zenodo.12664

# %%
#Using Zenodo:
urlz = "https://doi.org/10.5281/zenodo.12664" #DOI solver URL
headersz = {'Accept': 'application/vnd.citationstyles.csl+json;q=1.0'} #Type of response accepted
rz = requests.post(urlz, headers=headersz) #POST with headers
print("Status code = ",rz.status_code)
dataz = json.loads(rz.text) #Data is now a json object
for elem in dataz:
    print("\n",elem,":", dataz[elem])
# Out:
# Status code =  200
#
#  type : article-journal
#
#  id : https://doi.org/10.5281/zenodo.12664
#
#  categories : ['zenodo', 'figshare']
#
#  author : [{'family': 'Rietdijk', 'given': 'Frederik'}]
#
#  issued : {'date-parts': [[2014, 11, 12]]}
#
#  abstract : A quick comparison between ZENODO and figshare.
#
#  container-title : Zenodo
#
#  DOI : 10.5281/ZENODO.12664
#
#  publisher : Zenodo
#
#  title : Comparing Zenodo And Figshare
#
#  URL : https://zenodo.org/record/12664
#
#  copyright : Creative Commons Attribution 4.0
